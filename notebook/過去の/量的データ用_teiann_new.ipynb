# %% [markdown]
# # 量的データ用（For quantitaive data）
# [Methods]
# - Clustering methods : Kmeans, GMM, FSSEM, FSS-Kmeans
# - Allocation methods : random, proportional allocation, post stratification, optimal allocation

# %% [markdown]
# -------------
# ### ライブラリのインポート＆その他の設定（Importing Libraries & Other Settings）

# %%
# 基本的なライブラリ
import numpy as np
import pandas as pd
from numpy.typing import NDArray
from scipy import stats

# Scikit-learn関連
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.utils.validation import check_X_y

# 抽象基底クラス (ABC)
from abc import ABCMeta, abstractmethod

# タイピングのサポート
from typing import Optional

# シード設定
from lightning.pytorch import seed_everything

seed_everything(8)

# 可視化の設定
import matplotlib.pyplot as plt
import japanize_matplotlib

import itertools

plt.style.use("ggplot")

from collections import Counter
# Out:
# Seed set to 8

# %% [markdown]
# --------
# ### 実験設定

# %%
N_CLUSTERS = 2  # クラスタ数
N_FEATURES_TO_SELECT = 17  # 選択される最大の特徴量数

SAMPLE_SIZE = 1000  # 標本サイズ
DATA_SIZE = 100000  # データサイズ(df2)
N_TRIALS = 100  # 試行回数（標本平均を求める回数）
# N_EXPERIMENT = 1  # 分散を求める回数
m_VALUE = 2  # 各クラスタの最小標本数(最適標本配分)
RANDOM_STATE = 0  # 乱数シード
ALLOCATION_METHODS = [
    "ProportionalAllocation",
    "PostStratification",
    "OptimalAllocation",
]  # "RandomAllocation"はいれない
CLUSTERING_METHOD = "gmm"  # "gmm" or "kmeans"

SELECTING_FEATURES = (
    "all_features"  # "all_features" or "not_all_features" #特徴量をすべて選ぶかどうか
)

# %% [markdown]
# -----------
# ### データの前処理（Data Preprocessing）

# %% [markdown]
# ##### 外れ値を除去する関数

# %%
# 外れ値の除去
def remove_outliers_zscore(
    data: pd.DataFrame, metric: str, threshold: float = 2
) -> pd.DataFrame:
    z_scores = np.abs(stats.zscore(data[metric]))
    data = data[(z_scores < threshold)]
    return data

# %% [markdown]
# ##### メルカリデータ（df1：全部, df2：一部）

# %%
# df1(all the data)
df1 = pd.read_csv(
    R"C:\Users\HaruMomozu\Documents\aug_first_cpn_data_for_ab_test_sensibility_tsukuba.csv"
)
obj1 = "GMV"
features_list1 = [
    "hist_4_day_buy_num",
    "hist_4_day_gmv",
    "his_4_day_is_buy",
    "hist_30_day_buy_days",
    "hist_30_day_buy_num",
    "hist_30_day_gmv",
    "hist_30_day_buy_recency",
    "hist_30_day_pay_days",
    "hist_30_day_atpu",
    "hist_30_day_gpv",
    "hist_30_day_pay_recency",
    "hist_30_day_list_days",
    "hist_30_day_list_num",
    "hist_30_day_list_recency",
    "hist_30_day_like_count",
    "hist_30_day_like_count_not_deleted",
    "hist_30_day_like_recency",
]

# df2(subset of the data)
df2 = df1.iloc[:DATA_SIZE]
obj2 = obj1
features_list2 = features_list1

# %% [markdown]
# ##### 外れ値除去と標準化

# %%
df = df2  # choose from (df1, df2)
obj = obj2  # choose from (obj1, obj2)
features_list = features_list2  # choose from (features_list1, features_list2)

# 外れ値除去
df = remove_outliers_zscore(df, obj)

# 標準化
X = df[features_list]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(X)
X_scaled = pd.DataFrame(scaled_features, columns=features_list)

# 目的変数
y = df[obj]

# 行を詰める
df = df.reset_index(drop=True)

# %% [markdown]
# -------------
# ### 提案手法でクラスタリング

# %% [markdown]
# ##### Allocation_in_Wrapper Class
# とりあえずproportional でやってみる
# ・データによってはクラスタ数=3と指定した場合も2になることもある
# ⇒ この場合はstopする

# %%
class Allocation_in_Wrapper(BaseEstimator, TransformerMixin):
    def __init__(
        self,
        n_features_to_select: int,
        n_clusters: int,
        clustering_method: str = "kmeans",
        allocation_methods: list[str] = ["ProportionalAllocation"],
        sample_size: int = 10,
        n_trials: int = 100,
        m_value=2,
        M: Optional[NDArray] = None,
        random_state: int = 0,
        selecting_features: str = "all_features",
    ):
        self.n_features_to_select = n_features_to_select
        self.n_clusters = n_clusters
        self.clustering_method = clustering_method
        self.allocation_methods = allocation_methods
        self.sample_size = sample_size
        self.n_trials = n_trials
        self.m_value = m_value
        self.M = M
        self.random_state = random_state
        self.selecting_features = selecting_features

    def fss(
        self, X: pd.DataFrame, y: pd.DataFrame
    ) -> "Allocation_in_Wrapper":  ###これ自体は多分あってる
        X, y = check_X_y(X, y)
        n_features = X.shape[1]  # 総特徴量数
        self.selected_features_dict = {}
        self.final_cluster_assignments_dict = {}
        self.features_score_dict = {}

        # ランダムの分散を計算
        self.random_allocation_std = self.cauculate_random_std(X, y)
        print(self.random_allocation_std)

        # 特徴量選択
        for allocation_method in self.allocation_methods:
            print("[", allocation_method, "]")

            features_score_dict = {}  # 確認用

            # 選ばれた特徴量と残っている特徴量の初期化
            current_features = []
            remaining_features = list(range(n_features))
            if self.selecting_features == "not_all_features":
                best_score = -np.inf

            while len(current_features) < self.n_features_to_select:
                if self.selecting_features == "all_features":
                    best_score = -np.inf
                best_feature = None  # 選ぶ特徴量の初期化

                for feature in remaining_features:
                    temp_features = tuple(
                        current_features + [feature]
                    )  # 特徴量をひとつ加え、score計算    ###########ここまでok
                    print("temp_features", temp_features)
                    score = self.crit(X[:, temp_features], y, allocation_method)
                    print("score", score)
                    if score > best_score:
                        print("特徴量更新")
                        best_score = score
                        best_feature = feature

                if best_feature is not None:
                    current_features.append(
                        best_feature
                    )  # best feature をcurrent features に追加
                    num_of_features = len(current_features)
                    self.y_hat_df_random = self.cauculate_random_std(X, y)
                    print(
                        "num_of_features:",
                        num_of_features,
                        "current_features:",
                        current_features,
                        ", score:",
                        best_score,
                    )

                    features_score_dict[str(num_of_features)] = best_score  # 確認用

                    remaining_features.remove(
                        best_feature
                    )  # best feature をremaining features から取り除く
                    self.selected_features_ = current_features
                else:
                    break

                # 選ばれた特徴量サブセットでクラスタリング
                final_features = X[:, self.selected_features_]
                if self.clustering_method == "gmm":
                    final_model_ = GaussianMixture(
                        n_components=self.n_clusters,
                        random_state=self.random_state,
                        init_params="kmeans",
                    )
                elif self.clustering_method == "kmeans":
                    final_model_ = KMeans(
                        n_clusters=self.n_clusters, random_state=self.random_state
                    )
                else:
                    raise ValueError(
                        f"Unknown clustering method: {self.clustering_method}"
                    )

                final_model_.fit(final_features)
                self.final_cluster_assignments_dict[allocation_method] = (
                    final_model_.predict(final_features)
                )
                self.features_score_dict[allocation_method] = (
                    features_score_dict  # 確認用
                )

                self.selected_features_dict[allocation_method] = self.selected_features_

        return self

    def crit(
        self, X: pd.DataFrame, y: pd.DataFrame, allocation_method: str
    ) -> float:  ##これ自体は大丈夫
        # クラスタリング手法がGMMの場合
        if self.clustering_method == "gmm":
            em = GaussianMixture(
                n_components=self.n_clusters,
                random_state=self.random_state,
                init_params="kmeans",
            )
            em.fit(X)
            self.N_cluster_label = em.predict(X)
            self.N_cluster_size = np.bincount(
                self.N_cluster_label, minlength=self.n_clusters
            )

        # クラスタリング手法がKMEANSの場合
        if self.clustering_method == "kmeans":
            kmeans = KMeans(
                n_clusters=self.n_clusters,
                random_state=self.random_state,
            )
            kmeans.fit(X)
            self.N_cluster_label = kmeans.predict(X)
            self.N_cluster_size = np.bincount(
                self.N_cluster_label, minlength=self.n_clusters
            )

        if (
            0 in self.N_cluster_size
        ):  # 母集団のクラスタ数が十分でない場合score=0 にする(あとでかえる)
            score = 0
        else:  ###################
            error_variance_reduction_rate = self.cauculate_reduction_rate(
                X, y, allocation_method
            )
            score = error_variance_reduction_rate

        return score

    def cauculate_reduction_rate(
        self, X: pd.DataFrame, y: pd.DataFrame, allocation_method: str
    ) -> float:  ######これ自体は大丈夫
        # 各戦略の標本数に基づいて目的変数の平均を推定
        y_hats = []
        for random_state in range(N_TRIALS):
            if allocation_method == "PostStratification":
                y_hat = self.estimate_y_mean_post(X, y)
            else:
                y_hat = self.estimate_y_mean_other(X, y, allocation_method)
            y_hats.append(
                {
                    "policy": allocation_method,
                    "y_hat": y_hat,
                    "random_state": random_state,
                }
            )

        y_hat_df = pd.DataFrame(y_hats)
        y_hat_df["error"] = (
            y_hat_df["y_hat"] - y.mean()
        )  # 真の平均からの誤差をerrorカラムに追加

        non_random_allocation_std = y_hat_df["error"].var()
        # 削減率
        reduction_rate = (
            1 - non_random_allocation_std / self.random_allocation_std
        ) * 100

        return reduction_rate

    def cauculate_random_std(self, X, y):  # 多分あってる
        y_hats = []
        for random_state in range(self.n_trials):
            sample = np.random.choice(y, self.sample_size, replace=False)
            y_hat_random = sample.mean()
            y_hats.append(
                {
                    "policy": "RandomAllocation",
                    "y_hat": y_hat_random,
                    "random_state": random_state,
                }
            )

        y_hat_df = pd.DataFrame(y_hats)
        y_hat_df["error"] = y_hat_df["y_hat"] - y.mean()
        random_allocation_std = y_hat_df["error"].var()
        return random_allocation_std

    def estimate_y_mean_post(self, X, y) -> float:  # あってそう
        n_cluster_size = np.array([self.sample_size])

        weights = self.N_cluster_size / self.N_cluster_size.sum()
        y_hat = 0
        indices = np.arange(self.N_cluster_size.sum())
        y_array = np.array(y.tolist())
        n_indices = np.random.choice(indices, n_cluster_size[0], replace=False)
        n_label = np.array([self.N_cluster_label[i] for i in n_indices])
        n_new_labels = np.unique(n_label)
        for h in n_new_labels:
            index = np.where(n_label == h)[0]
            sample = y_array[n_indices[index]]
            y_sample_mean = sample.mean()  # サンプリングした標本の平均
            y_hat += y_sample_mean * weights[h]
        return y_hat

    def estimate_y_mean_other(self, X, y, allocation_method) -> float:  # 多分あっている
        if allocation_method == "ProportionalAllocation":
            n_cluster_size = self.ProportionalAllocation(X, y)
        if allocation_method == "OptimalAllocation":
            n_cluster_size = self.OptimalAllocation(X, y)

        weights = self.N_cluster_size / self.N_cluster_size.sum()
        y_hat = 0
        for h in range(n_cluster_size.shape[0]):
            if n_cluster_size[h] != 0:
                y_cluster = y[self.N_cluster_label == h]

                sample: NDArray = np.random.choice(
                    y_cluster, n_cluster_size[h], replace=False
                )
                y_sample_mean = sample.mean()  # サンプリングした標本の平均
                y_hat += y_sample_mean * weights[h]
        return y_hat

    def get_feature_index_out(self) -> dict[NDArray]:
        return self.selected_features_dict  # 選択された特徴量のインデックス

    def get_final_cluster_assignments(self) -> dict[NDArray]:
        return self.final_cluster_assignments_dict  # 最終的なクラスタリング結果

    def get_features_score(self) -> dict[dict]:
        return self.features_score_dict

    def ProportionalAllocation(self, X, y) -> NDArray:  # あってそう
        n_cluster_size: NDArray = np.round(
            self.N_cluster_size / self.N_cluster_size.sum() * self.sample_size
        ).astype(int)

        if n_cluster_size.sum() > self.sample_size:
            # nの合計がn_samplesより大きい場合は一番標本数が多いクラスタから削る
            n_cluster_size[np.argmax(n_cluster_size)] -= (
                n_cluster_size.sum() - self.sample_size
            )
        if n_cluster_size.sum() < self.sample_size:
            # nの合計がn_samplesより小さい場合は一番標本数が多いクラスタにたす
            n_cluster_size[np.argmax(n_cluster_size)] += (
                -n_cluster_size.sum() + self.sample_size
            )

        return n_cluster_size

    def OptimalAllocation(self, X, y) -> NDArray:  # たぶんあってる
        self.m = np.full(self.n_clusters, self.m_value)
        # S:クラスタ毎の目的変数のvarianceを要素とする配列 (H, )
        S = np.array(
            [np.var(y[self.N_cluster_label == h]) for h in range(self.n_clusters)]
        )
        d = (self.N_cluster_size**2) * S

        n_cluster_size = self.m.copy()  # 初期値

        M = self.M.copy() if self.M is not None else self.N_cluster_size.copy()
        I = np.arange(self.n_clusters)  # noqa #クラスタのインデックス
        while (n_cluster_size.sum() != self.sample_size) and len(I) != 0:
            delta = np.zeros(self.n_clusters)
            delta[I] = (d / (n_cluster_size + 1) - d / n_cluster_size)[I]
            h_star = np.argmin(delta[I])
            h_star = I[h_star]

            if n_cluster_size[h_star] + 1 <= M[h_star]:
                n_cluster_size[h_star] = n_cluster_size[h_star] + 1
            else:
                # Iの要素h_starを削除
                I_ = I.tolist()
                I_ = [i for i in I_ if i != h_star]
                I = np.array(I_)  # noqa

        # 制約チェック
        assert (
            n_cluster_size.sum() <= self.sample_size
        ), f"Total sample size is over than {self.sample_size}"
        assert np.all(
            n_cluster_size >= self.m
        ), "Minimum sample size constraint is not satisfied"
        if self.M is not None:
            assert np.all(
                n_cluster_size <= self.M
            ), "Maximum sample size constraint is not satisfied"

        return n_cluster_size

# %%
ins = Allocation_in_Wrapper(
    n_features_to_select=N_FEATURES_TO_SELECT,
    n_clusters=N_CLUSTERS,
    clustering_method=CLUSTERING_METHOD,
    allocation_methods=ALLOCATION_METHODS,
    sample_size=SAMPLE_SIZE,
    n_trials=N_TRIALS,
    m_value=m_VALUE,
    random_state=RANDOM_STATE,
    selecting_features=SELECTING_FEATURES,
)

ins.fss(X_scaled, y)
selected_features_index = ins.get_feature_index_out()
cluster_label = ins.get_final_cluster_assignments()
cluster_size = np.unique(cluster_label, return_counts=True)[1]
features_score_dict = ins.get_features_score()
print(features_score_dict)

for allocation, dict in features_score_dict.items():
    plt.bar(dict.keys(), dict.values())
    for key, value in dict.items():
        rounded_value = round(value, 2)
        plt.text(key, value + 0.3, str(rounded_value), ha="center")
    plt.title(f"evaluation score({allocation})")
    plt.xlabel("number of features")
    plt.ylabel("evaluation value")
    plt.show()
# Out:
# 17617.555138784952
# [ ProportionalAllocation ]
# temp_features (0,)
# c:\Users\HaruMomozu\Desktop\momozu\ABtesting\.venv\Lib\site-packages\threadpoolctl.py:1214: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# score -87.27275345378797
# 特徴量更新
# temp_features (1,)
# score -37.126111321629615
# 特徴量更新
# temp_features (2,)
# score -21.030022670532023
# 特徴量更新
# temp_features (3,)
# score -10.347424212030564
# 特徴量更新
# temp_features (4,)
# score -23.788105969700712
# temp_features (5,)
# score -36.77340777779896
# temp_features (6,)
# score -18.471370295242817
# temp_features (7,)
# score -37.80405662059558
# temp_features (8,)
# score -24.681801910717272
# temp_features (9,)
# score -20.574106669929847
# temp_features (10,)
# score 2.5814782920911883
# 特徴量更新
# temp_features (11,)
# score -6.567936178929767
# temp_features (12,)
# score -25.138258730915062
# temp_features (13,)
# score -39.846814870742044
# temp_features (14,)
# score -15.126010879044681
# temp_features (15,)
# score -31.522937428057098
# temp_features (16,)
# score -23.30087500323359
# num_of_features: 1 current_features: [10] , score: 2.5814782920911883
# temp_features (10, 0)
# score -42.00762831543064
# 特徴量更新
# temp_features (10, 1)
# score 5.020004788994936
# 特徴量更新
# temp_features (10, 2)
# score -5.108842036396588
# temp_features (10, 3)
# score -11.545666481539074
# temp_features (10, 4)
# score -9.266438403055123
# temp_features (10, 5)
# score -27.683199082281828
# temp_features (10, 6)
# score -59.849342749411804
# temp_features (10, 7)
# score 13.05106418035037
# 特徴量更新
# temp_features (10, 8)
# score 4.210333748504491
# temp_features (10, 9)
# score -20.54532027402647
# temp_features (10, 11)
# score -26.263173675548668
# temp_features (10, 12)
# score -59.969300722466514
# temp_features (10, 13)
# score -14.171875431004889
# temp_features (10, 14)
# score -12.403667970239152
# temp_features (10, 15)
# score -10.905530135884689
# temp_features (10, 16)
# score -29.97517552605342
# num_of_features: 2 current_features: [10, 7] , score: 13.05106418035037
# temp_features (10, 7, 0)
# score -34.93039139174516
# 特徴量更新
# temp_features (10, 7, 1)
# score -22.650822988757625
# 特徴量更新
# temp_features (10, 7, 2)
# score -31.996881070316196
# temp_features (10, 7, 3)
# score -53.15927508098017
# temp_features (10, 7, 4)
# score -32.962890633767316
# temp_features (10, 7, 5)
# score -3.383718735095975
# 特徴量更新
# temp_features (10, 7, 6)
# score -93.59227824438803
# temp_features (10, 7, 8)
# score -22.507637018600658
# temp_features (10, 7, 9)
# score -41.01185627549686
# temp_features (10, 7, 11)
# score -25.922631184348035
# temp_features (10, 7, 12)
# score -21.610966167000267
# temp_features (10, 7, 13)
# score -21.36381694288081
# temp_features (10, 7, 14)
# score -44.28961541297547
# temp_features (10, 7, 15)
# score -1.035954498443692
# 特徴量更新
# temp_features (10, 7, 16)
# score -34.528467837567824
# num_of_features: 3 current_features: [10, 7, 15] , score: -1.035954498443692
# temp_features (10, 7, 15, 0)
# score -28.925363787536384
# 特徴量更新
# temp_features (10, 7, 15, 1)
# score -12.728764992175968
# 特徴量更新
# temp_features (10, 7, 15, 2)
# score -0.6039811381385984
# 特徴量更新
# temp_features (10, 7, 15, 3)
# score 7.066284305515092
# 特徴量更新
# temp_features (10, 7, 15, 4)
# score -29.417305675705396
# temp_features (10, 7, 15, 5)
# score -54.408109582178234
# temp_features (10, 7, 15, 6)
# score -37.81115692610608
# temp_features (10, 7, 15, 8)
# score -8.457738779693692
# temp_features (10, 7, 15, 9)
# score -16.73677226453718
# temp_features (10, 7, 15, 11)
# score -19.3996304292547
# temp_features (10, 7, 15, 12)
# score -26.87939884606314
# temp_features (10, 7, 15, 13)
# score -31.490338957872144
# temp_features (10, 7, 15, 14)
# score 7.865456381447622
# 特徴量更新
# temp_features (10, 7, 15, 16)
# score -34.22017285535026
# num_of_features: 4 current_features: [10, 7, 15, 14] , score: 7.865456381447622
# temp_features (10, 7, 15, 14, 0)
# score -13.046822345330678
# 特徴量更新
# temp_features (10, 7, 15, 14, 1)
# score -13.371589489890546
# temp_features (10, 7, 15, 14, 2)
# score -23.35571116807582
# temp_features (10, 7, 15, 14, 3)
# score -18.362703458332994
# temp_features (10, 7, 15, 14, 4)
# score -19.91688425499143
# temp_features (10, 7, 15, 14, 5)
# score -48.64328182391513
# temp_features (10, 7, 15, 14, 6)
# score -57.25181508230715
# temp_features (10, 7, 15, 14, 8)
# score -14.103386803370777
# temp_features (10, 7, 15, 14, 9)
# score -36.86933435143658
# temp_features (10, 7, 15, 14, 11)
# score -21.16610762640223
# temp_features (10, 7, 15, 14, 12)
# score -47.46545598638503
# temp_features (10, 7, 15, 14, 13)
# score -31.418995255737237
# temp_features (10, 7, 15, 14, 16)
# score -49.3315802688197
# num_of_features: 5 current_features: [10, 7, 15, 14, 0] , score: -13.046822345330678
# temp_features (10, 7, 15, 14, 0, 1)
# score -15.871512110813768
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 2)
# score -43.60618595267114
# temp_features (10, 7, 15, 14, 0, 3)
# score -38.40937824612993
# temp_features (10, 7, 15, 14, 0, 4)
# score -20.76999746870378
# temp_features (10, 7, 15, 14, 0, 5)
# score -28.195598264567945
# temp_features (10, 7, 15, 14, 0, 6)
# score -29.679121135398724
# temp_features (10, 7, 15, 14, 0, 8)
# score 1.6395950403492288
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 9)
# score -34.51784167190266
# temp_features (10, 7, 15, 14, 0, 11)
# score -39.66967750110404
# temp_features (10, 7, 15, 14, 0, 12)
# score -23.031265267481228
# temp_features (10, 7, 15, 14, 0, 13)
# score -33.444338011648476
# temp_features (10, 7, 15, 14, 0, 16)
# score -52.95938916608793
# num_of_features: 6 current_features: [10, 7, 15, 14, 0, 8] , score: 1.6395950403492288
# temp_features (10, 7, 15, 14, 0, 8, 1)
# score -20.902088564025444
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 2)
# score -23.026044840573423
# temp_features (10, 7, 15, 14, 0, 8, 3)
# score -29.92169606565218
# temp_features (10, 7, 15, 14, 0, 8, 4)
# score -31.393911235061587
# temp_features (10, 7, 15, 14, 0, 8, 5)
# score -30.392738675562757
# temp_features (10, 7, 15, 14, 0, 8, 6)
# score -36.40388058507851
# temp_features (10, 7, 15, 14, 0, 8, 9)
# score -31.871705809888738
# temp_features (10, 7, 15, 14, 0, 8, 11)
# score -19.64400002386877
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 12)
# score -57.0104435618199
# temp_features (10, 7, 15, 14, 0, 8, 13)
# score -23.882277628373892
# temp_features (10, 7, 15, 14, 0, 8, 16)
# score -37.23595123138226
# num_of_features: 7 current_features: [10, 7, 15, 14, 0, 8, 11] , score: -19.64400002386877
# temp_features (10, 7, 15, 14, 0, 8, 11, 1)
# score -1.0292431804368896
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 2)
# score -21.02541297711418
# temp_features (10, 7, 15, 14, 0, 8, 11, 3)
# score -37.59955063068085
# temp_features (10, 7, 15, 14, 0, 8, 11, 4)
# score -20.610661452668833
# temp_features (10, 7, 15, 14, 0, 8, 11, 5)
# score -57.177926530118505
# temp_features (10, 7, 15, 14, 0, 8, 11, 6)
# score -32.9084247209694
# temp_features (10, 7, 15, 14, 0, 8, 11, 9)
# score -88.91847911642314
# temp_features (10, 7, 15, 14, 0, 8, 11, 12)
# score -16.84264633182222
# temp_features (10, 7, 15, 14, 0, 8, 11, 13)
# score -69.1199699549675
# temp_features (10, 7, 15, 14, 0, 8, 11, 16)
# score -25.964092182678367
# num_of_features: 8 current_features: [10, 7, 15, 14, 0, 8, 11, 1] , score: -1.0292431804368896
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 2)
# score -27.326294327769475
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 3)
# score -23.137884331256075
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 4)
# score -29.600364544925874
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 5)
# score -53.90890789433791
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 6)
# score -19.695212512904405
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9)
# score -3.407050770252096
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 12)
# score -14.879060908264009
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 13)
# score -9.445771636802181
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 16)
# score -30.293796278048113
# num_of_features: 9 current_features: [10, 7, 15, 14, 0, 8, 11, 1, 9] , score: -3.407050770252096
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 2)
# score -36.37064947735815
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 3)
# score -26.5169518200546
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 4)
# score -41.405838915113314
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5)
# score -6.961968785225192
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 6)
# score -54.534180205062796
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 12)
# score -25.233395332833396
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 13)
# score -16.14616689416364
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 16)
# score -27.909542717683355
# num_of_features: 10 current_features: [10, 7, 15, 14, 0, 8, 11, 1, 9, 5] , score: -6.961968785225192
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 2)
# score -14.751185936055933
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3)
# score 5.074040320433692
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 4)
# score -48.48223114287131
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 6)
# score -56.810535371181544
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 12)
# score -33.03032482839237
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 13)
# score -13.442753642788574
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 16)
# score -44.19630280003486
# num_of_features: 11 current_features: [10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3] , score: 5.074040320433692
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 2)
# score -19.289652343668106
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4)
# score 4.78615895340263
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 6)
# score -28.34238801438285
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 12)
# score -42.39548872705683
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 13)
# score -48.62176742376045
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 16)
# score -30.844718959191695
# num_of_features: 12 current_features: [10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4] , score: 4.78615895340263
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 2)
# score -28.494917263075248
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 6)
# score -18.40461257934325
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 12)
# score -30.996938635732274
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13)
# score -12.10057177056727
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 16)
# score -31.44442180696645
# num_of_features: 13 current_features: [10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13] , score: -12.10057177056727
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 2)
# score -28.887558866068485
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 6)
# score -36.31138852124318
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 12)
# score -20.568470585596586
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 16)
# score -63.87418939934359
# num_of_features: 14 current_features: [10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 12] , score: -20.568470585596586
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 12, 2)
# score -35.022228897487025
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 12, 6)
# score -43.052587568392696
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 12, 16)
# score -45.532746260150184
# num_of_features: 15 current_features: [10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 12, 2] , score: -35.022228897487025
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 12, 2, 6)
# score -19.502463886368517
# 特徴量更新
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 12, 2, 16)
# score -43.94476412994565
# num_of_features: 16 current_features: [10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 12, 2, 6] , score: -19.502463886368517
# temp_features (10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 12, 2, 6, 16)
# score -58.1841713905636
# 特徴量更新
# num_of_features: 17 current_features: [10, 7, 15, 14, 0, 8, 11, 1, 9, 5, 3, 4, 13, 12, 2, 6, 16] , score: -58.1841713905636
# [ PostStratification ]
# temp_features (0,)
# score -17.742941849505755
# 特徴量更新
# temp_features (1,)
# score -16.756676042050668
# 特徴量更新
# temp_features (2,)
# score -25.06413301124364
# temp_features (3,)
# score -3.3269737983331105
# 特徴量更新
# temp_features (4,)
# score -12.773269575722313
# temp_features (5,)
# score -14.088768294065757
# temp_features (6,)
# score -20.495699911397903
# temp_features (7,)
# score -2.057369598091374
# 特徴量更新
# temp_features (8,)
# score -29.548673975578833
# temp_features (9,)
# score -19.16520101273571
# temp_features (10,)
# score -23.971558878887645
# temp_features (11,)
# score -28.93254863821999
# temp_features (12,)
# score -33.731827933147706
# temp_features (13,)
# score -44.621044645449246
# temp_features (14,)
# score -36.360365130150555
# temp_features (15,)
# score -15.833665577894273
# temp_features (16,)
# score -27.528404118833105
# num_of_features: 1 current_features: [7] , score: -2.057369598091374
# temp_features (7, 0)
# score -35.00771458048273
# 特徴量更新
# temp_features (7, 1)
# score -17.496843062081634
# 特徴量更新
# temp_features (7, 2)
# score -0.29173123380141774
# 特徴量更新
# temp_features (7, 3)
# score -42.77419463318104
# temp_features (7, 4)
# score -28.556167562440837
# temp_features (7, 5)
# score -73.41211076857981
# temp_features (7, 6)
# score -32.916899876843765
# temp_features (7, 8)
# score -31.148233578412544
# temp_features (7, 9)
# score -51.2296595967896
# temp_features (7, 10)
# score -37.745193236460636
# temp_features (7, 11)
# score -38.32676837734681
# temp_features (7, 12)
# score -18.89525431156933
# temp_features (7, 13)
# score -26.878727445268712
# temp_features (7, 14)
# score -32.61286228392806
# temp_features (7, 15)
# score -16.67406604620718
# temp_features (7, 16)
# score -33.023090817894854
# num_of_features: 2 current_features: [7, 2] , score: -0.29173123380141774
# temp_features (7, 2, 0)
# score -29.334656478290235
# 特徴量更新
# temp_features (7, 2, 1)
# score -40.181432141275586
# temp_features (7, 2, 3)
# score -54.909311483442224
# temp_features (7, 2, 4)
# score -39.53746871958374
# temp_features (7, 2, 5)
# score -54.14761763423186
# temp_features (7, 2, 6)
# score -27.530915809968292
# 特徴量更新
# temp_features (7, 2, 8)
# score -11.006290006640572
# 特徴量更新
# temp_features (7, 2, 9)
# score -13.048342575304295
# temp_features (7, 2, 10)
# score -31.17660230411523
# temp_features (7, 2, 11)
# score -25.284457369280954
# temp_features (7, 2, 12)
# score 6.160351813426357
# 特徴量更新
# temp_features (7, 2, 13)
# score -23.0075799330937
# temp_features (7, 2, 14)
# score 5.11880787457486
# temp_features (7, 2, 15)
# score -19.971932634553614
# temp_features (7, 2, 16)
# score -38.584503750058886
# num_of_features: 3 current_features: [7, 2, 12] , score: 6.160351813426357
# temp_features (7, 2, 12, 0)
# score -29.4356551775087
# 特徴量更新
# temp_features (7, 2, 12, 1)
# score -21.79780942303431
# 特徴量更新
# temp_features (7, 2, 12, 3)
# score -13.053394530818775
# 特徴量更新
# temp_features (7, 2, 12, 4)
# score -32.36911465352081
# temp_features (7, 2, 12, 5)
# score -3.4869088613890264
# 特徴量更新
# temp_features (7, 2, 12, 6)
# score -17.066314941659712
# temp_features (7, 2, 12, 8)
# score -20.20370884365972
# temp_features (7, 2, 12, 9)
# score -10.508209293266347
# temp_features (7, 2, 12, 10)
# score -39.73316637232334
# temp_features (7, 2, 12, 11)
# score -18.14538150603029
# temp_features (7, 2, 12, 13)
# score -33.39740380586653
# temp_features (7, 2, 12, 14)
# score -1.808281092027042
# 特徴量更新
# temp_features (7, 2, 12, 15)
# score -46.28794523189379
# temp_features (7, 2, 12, 16)
# score -45.16063354597981
# num_of_features: 4 current_features: [7, 2, 12, 14] , score: -1.808281092027042
# temp_features (7, 2, 12, 14, 0)
# score -14.062735913971714
# 特徴量更新
# temp_features (7, 2, 12, 14, 1)
# score -71.03373394044885
# temp_features (7, 2, 12, 14, 3)
# score -31.317382935260028
# temp_features (7, 2, 12, 14, 4)
# score -46.14277523918846
# temp_features (7, 2, 12, 14, 5)
# score -58.71599548674773
# temp_features (7, 2, 12, 14, 6)
# score -38.600047580916666
# temp_features (7, 2, 12, 14, 8)
# score 9.994502772673897
# 特徴量更新
# temp_features (7, 2, 12, 14, 9)
# score -45.895385330375824
# temp_features (7, 2, 12, 14, 10)
# score -25.34981103050058
# temp_features (7, 2, 12, 14, 11)
# score -28.622990120494496
# temp_features (7, 2, 12, 14, 13)
# score -11.059120356679841
# temp_features (7, 2, 12, 14, 15)
# score -45.356154020720176
# temp_features (7, 2, 12, 14, 16)
# score -74.5566067376878
# num_of_features: 5 current_features: [7, 2, 12, 14, 8] , score: 9.994502772673897
# temp_features (7, 2, 12, 14, 8, 0)
# score -30.46253899447544
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 1)
# score -12.69647930761666
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 3)
# score -41.47516135871421
# temp_features (7, 2, 12, 14, 8, 4)
# score -39.135979877530346
# temp_features (7, 2, 12, 14, 8, 5)
# score -25.163159627873057
# temp_features (7, 2, 12, 14, 8, 6)
# score -26.95586162768384
# temp_features (7, 2, 12, 14, 8, 9)
# score -1.6202572282198124
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 10)
# score -19.033987189646528
# temp_features (7, 2, 12, 14, 8, 11)
# score -17.67484730313047
# temp_features (7, 2, 12, 14, 8, 13)
# score -28.052662032859832
# temp_features (7, 2, 12, 14, 8, 15)
# score -58.356027785920595
# temp_features (7, 2, 12, 14, 8, 16)
# score -4.250963331084212
# num_of_features: 6 current_features: [7, 2, 12, 14, 8, 9] , score: -1.6202572282198124
# temp_features (7, 2, 12, 14, 8, 9, 0)
# score -43.99022474819061
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 1)
# score -52.637166436690144
# temp_features (7, 2, 12, 14, 8, 9, 3)
# score -31.802021666006585
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 4)
# score -48.07886495697635
# temp_features (7, 2, 12, 14, 8, 9, 5)
# score -33.48711818152543
# temp_features (7, 2, 12, 14, 8, 9, 6)
# score -44.36074058569166
# temp_features (7, 2, 12, 14, 8, 9, 10)
# score -23.042320665713056
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 11)
# score -32.28546132629726
# temp_features (7, 2, 12, 14, 8, 9, 13)
# score -28.257602456713627
# temp_features (7, 2, 12, 14, 8, 9, 15)
# score -26.231493143664398
# temp_features (7, 2, 12, 14, 8, 9, 16)
# score -19.444175355052316
# 特徴量更新
# num_of_features: 7 current_features: [7, 2, 12, 14, 8, 9, 16] , score: -19.444175355052316
# temp_features (7, 2, 12, 14, 8, 9, 16, 0)
# score -36.09293179578754
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 1)
# score -38.21216461217227
# temp_features (7, 2, 12, 14, 8, 9, 16, 3)
# score -26.516679236522144
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 4)
# score -42.764134721699506
# temp_features (7, 2, 12, 14, 8, 9, 16, 5)
# score -25.007264507937688
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6)
# score -5.048268502439557
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 10)
# score -5.7644413194301025
# temp_features (7, 2, 12, 14, 8, 9, 16, 11)
# score -52.45863020443669
# temp_features (7, 2, 12, 14, 8, 9, 16, 13)
# score -47.11468793007878
# temp_features (7, 2, 12, 14, 8, 9, 16, 15)
# score -6.992232832631706
# num_of_features: 8 current_features: [7, 2, 12, 14, 8, 9, 16, 6] , score: -5.048268502439557
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 0)
# score -16.750524797028277
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 1)
# score -23.555550630313004
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 3)
# score -59.356607174334776
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 4)
# score -59.87947185443036
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 5)
# score -29.600771746711295
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 10)
# score -57.073162379255194
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 11)
# score -17.559137799378256
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 13)
# score -20.59408016013049
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15)
# score -7.700604860030058
# 特徴量更新
# num_of_features: 9 current_features: [7, 2, 12, 14, 8, 9, 16, 6, 15] , score: -7.700604860030058
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0)
# score -4.412737703339098
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 1)
# score -46.04423589432838
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 3)
# score -15.724128274032667
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 4)
# score -65.09588343621853
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 5)
# score -35.22563297120409
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 10)
# score -51.876910285804186
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 11)
# score -25.47643154738757
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 13)
# score -19.074674335770503
# num_of_features: 10 current_features: [7, 2, 12, 14, 8, 9, 16, 6, 15, 0] , score: -4.412737703339098
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 1)
# score -14.688469241270141
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 3)
# score -32.35610554224155
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 4)
# score -10.767951493031958
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 5)
# score -52.173834188513
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 10)
# score -23.82914124692683
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 11)
# score -4.77557842989591
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13)
# score -3.362972903261441
# 特徴量更新
# num_of_features: 11 current_features: [7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13] , score: -3.362972903261441
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 1)
# score -27.504359244333166
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 3)
# score -33.528719342063454
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4)
# score -19.60371774252394
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 5)
# score -30.79570346929561
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 10)
# score -56.595366907376544
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 11)
# score -32.956297343459305
# num_of_features: 12 current_features: [7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4] , score: -19.60371774252394
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 1)
# score -24.021064183046214
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 3)
# score -18.173625600779243
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5)
# score -3.746317540442301
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 10)
# score -20.891177497114597
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 11)
# score -29.77272086626812
# num_of_features: 13 current_features: [7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5] , score: -3.746317540442301
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 1)
# score -14.998576376519534
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 3)
# score -3.5060725643665247
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 10)
# score -33.29524414050895
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 11)
# score -8.634252036970768
# num_of_features: 14 current_features: [7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 3] , score: -3.5060725643665247
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 3, 1)
# score -44.92560266466812
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 3, 10)
# score -1.5590885664966692
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 3, 11)
# score -23.3674345235928
# num_of_features: 15 current_features: [7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 3, 10] , score: -1.5590885664966692
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 3, 10, 1)
# score -32.866184547747345
# 特徴量更新
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 3, 10, 11)
# score -12.030007686006105
# 特徴量更新
# num_of_features: 16 current_features: [7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 3, 10, 11] , score: -12.030007686006105
# temp_features (7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 3, 10, 11, 1)
# score -42.42488903854249
# 特徴量更新
# num_of_features: 17 current_features: [7, 2, 12, 14, 8, 9, 16, 6, 15, 0, 13, 4, 5, 3, 10, 11, 1] , score: -42.42488903854249
# [ OptimalAllocation ]
# temp_features (0,)
# score -37.71075699995783
# 特徴量更新
# temp_features (1,)
# score -47.04302195104193
# temp_features (2,)
# score -29.850806423249598
# 特徴量更新
# temp_features (3,)
# score -15.081668361777577
# 特徴量更新
# temp_features (4,)
# score -26.23274630753314
# temp_features (5,)
# score 9.706293826398316
# 特徴量更新
# temp_features (6,)
# score -17.69490562505649
# temp_features (7,)
# score -21.876058634891127
# temp_features (8,)
# score -48.44834790987744
# temp_features (9,)
# score -18.38503152466131
# temp_features (10,)
# score -43.5019061349881
# temp_features (11,)
# score 4.6735301517851
# temp_features (12,)
# score -44.50556791116578
# temp_features (13,)
# score -52.907157439499606
# temp_features (14,)
# score -19.89980603345125
# temp_features (15,)
# score -31.338977996318906
# temp_features (16,)
# score -12.677205376427004
# num_of_features: 1 current_features: [5] , score: 9.706293826398316
# temp_features (5, 0)
# score 4.653053931104056
# 特徴量更新
# temp_features (5, 1)
# score 22.25235582971695
# 特徴量更新
# temp_features (5, 2)
# score -0.9511686754785087
# temp_features (5, 3)
# score -19.859314512518033
# temp_features (5, 4)
# score -0.8854431894383508
# temp_features (5, 6)
# score -11.839626863546604
# temp_features (5, 7)
# score 7.329083412381843
# temp_features (5, 8)
# score -28.75151016295949
# temp_features (5, 9)
# score -24.898841084992295
# temp_features (5, 10)
# score -16.951089906619554
# temp_features (5, 11)
# score 0.5407027086168692
# temp_features (5, 12)
# score -0.5653661835784529
# temp_features (5, 13)
# score -7.15854161014744
# temp_features (5, 14)
# score 28.484569943449813
# 特徴量更新
# temp_features (5, 15)
# score 7.61476119700858
# temp_features (5, 16)
# score 7.470201521812603
# num_of_features: 2 current_features: [5, 14] , score: 28.484569943449813
# temp_features (5, 14, 0)
# score 10.661420831286605
# 特徴量更新
# temp_features (5, 14, 1)
# score 9.0097620654774
# temp_features (5, 14, 2)
# score -30.49653013458442
# temp_features (5, 14, 3)
# score -16.79892072624549
# temp_features (5, 14, 4)
# score 21.82943107757379
# 特徴量更新
# temp_features (5, 14, 6)
# score 11.15091903156874
# temp_features (5, 14, 7)
# score -45.829205935811814
# temp_features (5, 14, 8)
# score -29.44336583510374
# temp_features (5, 14, 9)
# score -25.27224957451457
# temp_features (5, 14, 10)
# score -59.49343606192055
# temp_features (5, 14, 11)
# score 13.811083022600979
# temp_features (5, 14, 12)
# score 10.579482823537735
# temp_features (5, 14, 13)
# score -1.3890475687247772
# temp_features (5, 14, 15)
# score 8.421699269462524
# temp_features (5, 14, 16)
# score -26.492613440189693
# num_of_features: 3 current_features: [5, 14, 4] , score: 21.82943107757379
# temp_features (5, 14, 4, 0)
# score -25.158420566884885
# 特徴量更新
# temp_features (5, 14, 4, 1)
# score -4.29226682216215
# 特徴量更新
# temp_features (5, 14, 4, 2)
# score -8.231148958166568
# temp_features (5, 14, 4, 3)
# score -0.32949680214731103
# 特徴量更新
# temp_features (5, 14, 4, 6)
# score 1.2481949458871155
# 特徴量更新
# temp_features (5, 14, 4, 7)
# score -6.662848658793719
# temp_features (5, 14, 4, 8)
# score 6.892501943554508
# 特徴量更新
# temp_features (5, 14, 4, 9)
# score -67.38041281669014
# temp_features (5, 14, 4, 10)
# score -16.58311409002009
# temp_features (5, 14, 4, 11)
# score -12.4672431917374
# temp_features (5, 14, 4, 12)
# score -3.0732337265170218
# temp_features (5, 14, 4, 13)
# score -2.5162997072446736
# temp_features (5, 14, 4, 15)
# score 12.750153599903646
# 特徴量更新
# temp_features (5, 14, 4, 16)
# score -22.06242870447006
# num_of_features: 4 current_features: [5, 14, 4, 15] , score: 12.750153599903646
# temp_features (5, 14, 4, 15, 0)
# score -39.32282365846298
# 特徴量更新
# temp_features (5, 14, 4, 15, 1)
# score -4.222820571024077
# 特徴量更新
# temp_features (5, 14, 4, 15, 2)
# score -29.839054277719068
# temp_features (5, 14, 4, 15, 3)
# score 5.798426743405283
# 特徴量更新
# temp_features (5, 14, 4, 15, 6)
# score 9.813721359708582
# 特徴量更新
# temp_features (5, 14, 4, 15, 7)
# score 21.55102750589286
# 特徴量更新
# temp_features (5, 14, 4, 15, 8)
# score 16.135193880054764
# temp_features (5, 14, 4, 15, 9)
# score -4.309442027233956
# temp_features (5, 14, 4, 15, 10)
# score -7.398126569051966
# temp_features (5, 14, 4, 15, 11)
# score 9.823114728354431
# temp_features (5, 14, 4, 15, 12)
# score -16.980555903913675
# temp_features (5, 14, 4, 15, 13)
# score -23.367990903980274
# temp_features (5, 14, 4, 15, 16)
# score -3.667946379518683
# num_of_features: 5 current_features: [5, 14, 4, 15, 7] , score: 21.55102750589286
# temp_features (5, 14, 4, 15, 7, 0)
# score -7.076610853410803
# 特徴量更新
# temp_features (5, 14, 4, 15, 7, 1)
# score -13.221436379328821
# temp_features (5, 14, 4, 15, 7, 2)
# score -43.09975462759983
# temp_features (5, 14, 4, 15, 7, 3)
# score -17.290326237186914
# temp_features (5, 14, 4, 15, 7, 6)
# score -51.39256072483293
# temp_features (5, 14, 4, 15, 7, 8)
# score -6.6963996566034245
# 特徴量更新
# temp_features (5, 14, 4, 15, 7, 9)
# score -29.541850029982996
# temp_features (5, 14, 4, 15, 7, 10)
# score -33.72801424799994
# temp_features (5, 14, 4, 15, 7, 11)
# score -19.465934304240772
# temp_features (5, 14, 4, 15, 7, 12)
# score -0.18604622308420193
# 特徴量更新
# temp_features (5, 14, 4, 15, 7, 13)
# score 10.326175636501755
# 特徴量更新
# temp_features (5, 14, 4, 15, 7, 16)
# score -1.3975635320487845
# num_of_features: 6 current_features: [5, 14, 4, 15, 7, 13] , score: 10.326175636501755
# temp_features (5, 14, 4, 15, 7, 13, 0)
# score 1.4366408515538498
# 特徴量更新
# temp_features (5, 14, 4, 15, 7, 13, 1)
# score -5.114623103089189
# temp_features (5, 14, 4, 15, 7, 13, 2)
# score -8.364894642948052
# temp_features (5, 14, 4, 15, 7, 13, 3)
# score -10.006521714699957
# temp_features (5, 14, 4, 15, 7, 13, 6)
# score -21.62951918134548
# temp_features (5, 14, 4, 15, 7, 13, 8)
# score -60.726220153806445
# temp_features (5, 14, 4, 15, 7, 13, 9)
# score -53.49671281906947
# temp_features (5, 14, 4, 15, 7, 13, 10)
# score -2.5290751855429727
# temp_features (5, 14, 4, 15, 7, 13, 11)
# score -46.66513988657188
# temp_features (5, 14, 4, 15, 7, 13, 12)
# score 20.120391766894187
# 特徴量更新
# temp_features (5, 14, 4, 15, 7, 13, 16)
# score -4.107460918211414
# num_of_features: 7 current_features: [5, 14, 4, 15, 7, 13, 12] , score: 20.120391766894187
# temp_features (5, 14, 4, 15, 7, 13, 12, 0)
# score -12.004482330583954
# 特徴量更新
# temp_features (5, 14, 4, 15, 7, 13, 12, 1)
# score -2.632368863040213
# 特徴量更新
# temp_features (5, 14, 4, 15, 7, 13, 12, 2)
# score -6.255111889128995
# temp_features (5, 14, 4, 15, 7, 13, 12, 3)
# score -10.357189895658081
# temp_features (5, 14, 4, 15, 7, 13, 12, 6)
# score -13.292375795538458
# temp_features (5, 14, 4, 15, 7, 13, 12, 8)
# score -55.37200425919504
# temp_features (5, 14, 4, 15, 7, 13, 12, 9)
# score -19.263293063512776
# temp_features (5, 14, 4, 15, 7, 13, 12, 10)
# score -0.5155428268927453
# 特徴量更新
# temp_features (5, 14, 4, 15, 7, 13, 12, 11)
