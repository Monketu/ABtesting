# %% [markdown]
# # 量的データ用（For quantitaive data）
# [Methods]
# - Clustering methods : Kmeans, GMM, FSSEM, FSS-Kmeans
# - Allocation methods : random, proportional allocation, post stratification, optimal allocation

# %% [markdown]
# -------------
# ### ライブラリのインポート＆その他の設定（Importing Libraries & Other Settings）

# %%
# 基本的なライブラリ
import numpy as np
import pandas as pd
from numpy.typing import NDArray
from scipy import stats

# Scikit-learn関連
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.utils.validation import check_X_y

# 抽象基底クラス (ABC)
from abc import ABCMeta, abstractmethod

# タイピングのサポート
from typing import Optional

# シード設定
from lightning.pytorch import seed_everything

# seed_everything(8)

# 可視化の設定
import matplotlib.pyplot as plt
import japanize_matplotlib
import itertools

plt.style.use("ggplot")

# %% [markdown]
# --------
# ### 実験設定

# %%
THRESHOLD = 2  # 外れ値除外の閾値

SAMPLE_SIZE = 100  # 標本サイズ
DATA_SIZE = 100000  # データサイズ(df2)
N_TRIALS = 10000  # 試行回数（標本平均を求める回数）
N_EXPERIMENT = 1  # 分散を求める回数
m_VALUE = 2  # 各クラスタの最小標本数(最適標本配分)
RANDOM_STATE = 0  # 乱数シード

ALLOCATION_METHODS = [
    "Proportional",
    "Post",
    "Optimal",
]  # Randomはいれない
CLUSTERING_METHOD = "kmeans"  # "gmm" or "kmeans" or "xmeans"

if CLUSTERING_METHOD == "kmeans":
    CLUSTERING_METHOD_NAME = "K-means"
if CLUSTERING_METHOD == "xmeans":
    CLUSTERING_METHOD_NAME == "X-means"
if CLUSTERING_METHOD == "gmm":
    CLUSTERING_METHOD_NAME == "GMM"

# クラスタを固定する場合(gmm, kmeans)
N_CLUSTERS = 10  # クラスタ数
# クラスタ数を固定しない場合（xmeans)
K_MIN = 2
K_MAX = 10


MAXIMUM_FEATURES_TO_SELECT = 17  # 選択される最大の特徴量数

SELECTING_FEATURES = "all_features"  # 特徴量をmaxになるまで選ぶ⇒"all_features" or 基準値が最大になるまで⇒"not_all_features"

# %% [markdown]
# -----------
# ### データの前処理（Data Preprocessing）

# %% [markdown]
# ##### 外れ値を除去する関数

# %%
# 外れ値の除去
def remove_outliers_zscore(
    data: pd.DataFrame, metric: str, threshold: float = 2
) -> pd.DataFrame:
    z_scores = np.abs(stats.zscore(data[metric]))
    data = data[(z_scores < threshold)]
    return data

# %% [markdown]
# ##### メルカリデータ（df1：全部, df2：一部）

# %%
# df1(all the data)
df1 = pd.read_csv(
    R"C:\Users\HaruMomozu\Documents\aug_first_cpn_data_for_ab_test_sensibility_tsukuba.csv"
)
obj1 = "GMV"
features_list1 = [
    "hist_4_day_buy_num",
    "hist_4_day_gmv",
    "his_4_day_is_buy",
    "hist_30_day_buy_days",
    "hist_30_day_buy_num",
    "hist_30_day_gmv",
    "hist_30_day_buy_recency",
    "hist_30_day_pay_days",
    "hist_30_day_atpu",
    "hist_30_day_gpv",
    "hist_30_day_pay_recency",
    "hist_30_day_list_days",
    "hist_30_day_list_num",
    "hist_30_day_list_recency",
    "hist_30_day_like_count",
    "hist_30_day_like_count_not_deleted",
    "hist_30_day_like_recency",
]

# df2(subset of the data)
df2 = df1.iloc[:DATA_SIZE]
obj2 = obj1
features_list2 = features_list1

# %% [markdown]
# ##### 外れ値除去と標準化

# %%
df = df2  # choose from (df1, df2)
obj = obj2  # choose from (obj1, obj2)
features_list = features_list2  # choose from (features_list1, features_list2)

# 外れ値除去
df = remove_outliers_zscore(data=df, metric=obj, threshold=THRESHOLD)

# 標準化
X = df[features_list]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(X)
X_scaled = pd.DataFrame(scaled_features, columns=features_list)

# 目的変数
y = df[obj]

# 行を詰める
df = df.reset_index(drop=True)

print("外れ値除外前のデータ数:", DATA_SIZE)
print("外れ値除外後のデータ数:", len(df))
# Out:
# 外れ値除外前のデータ数: 100000
# 外れ値除外後のデータ数: 99082

# %% [markdown]
# -------------------------
# ### 単純無作為抽出（Random）の誤差分散を計算

# %%
RANDOM_STD_LIST = []
for exp in range(N_EXPERIMENT):
    y_hats = []
    np.random.seed(exp)
    for random_state in range(N_TRIALS):
        sample = np.random.choice(y, SAMPLE_SIZE, replace=False)
        y_hat_random = sample.mean()
        y_hats.append(y_hat_random)
    errors = np.array(y_hats) - y.mean()
    random_std = errors.var()
    RANDOM_STD_LIST.append(random_std)
print(RANDOM_STD_LIST)
# Out:
# [232437.5132330648]

# %% [markdown]
# -------------
# ### 提案手法でクラスタリングと特徴量選択と標本配分

# %% [markdown]
# ##### Allocation_in_Wrapper Class

# %%
class Allocation_in_Wrapper(BaseEstimator, TransformerMixin):
    def __init__(
        self,
        maximum_features_to_select: int,
        n_clusters: int,
        clustering_method: str = "kmeans",
        allocation_methods: list[str] = ["Proportional"],
        sample_size: int = 10,
        n_trials: int = 100,
        m_value=2,
        M: Optional[NDArray] = None,
        random_state: int = 0,
        selecting_features: str = "all_features",
        k_min: int = 2,
        k_max: int = 10,
        random_allocation_std: float = 0.1,
        exp_num: int = 0,
    ):
        self.maximum_features_to_select = maximum_features_to_select
        self.n_clusters = n_clusters
        self.clustering_method = clustering_method
        self.allocation_methods = allocation_methods
        self.sample_size = sample_size
        self.n_trials = n_trials
        self.m_value = m_value
        self.M = M
        self.random_state = random_state
        self.selecting_features = selecting_features
        self.k_min = k_min
        self.k_max = k_max
        self.random_allocation_std = random_allocation_std
        self.exp_num = exp_num

    def fss(self, X: pd.DataFrame, y: pd.DataFrame) -> "Allocation_in_Wrapper":
        X, y = check_X_y(X, y)
        n_all_features = X.shape[1]  # 総特徴量数
        self.final_selected_features_dict = {}  # キー：標本配分手法, 値：最終的に選ばれた特徴量のリスト
        self.final_cluster_assignments_dict = {}  # キー：標本配分手法, 値：最終的なクラスタラベル
        self.features_score_dict_dict = {}  # キー：標本配分手法, 値：features_score_dict
        self.features_error_variance_dict_dict = {}  # キー：標本配分手法, 値：features_error_variance_dict
        self.final_n_clusters_dict = {}  # キー：標本配分手法, 値：最終的なクラスタ数
        self.final_score_dict = {}
        self.final_error_variance_dict = {}

        # 特徴量選択
        for allocation_method in self.allocation_methods:
            print("[", allocation_method, "]")

            features_score_dict = {}
            features_error_variance_dict = {}

            # 選ばれた特徴量と残っている特徴量の初期化
            current_features = []
            remaining_features = list(range(n_all_features))
            best_labels = [-1 for i in range(len(X))]
            best_n_clusters = -1
            if self.selecting_features == "not_all_features":
                best_score = -np.inf

            while len(current_features) < self.maximum_features_to_select:
                if self.selecting_features == "all_features":
                    best_score = -np.inf
                best_feature = None  # 選ぶ特徴量の初期化

                for feature in remaining_features:
                    temp_features = tuple(
                        current_features + [feature]
                    )  # 特徴量をひとつ加え、score計算
                    score, error_variance, n_clusters = self.crit(
                        X[:, temp_features], y, allocation_method
                    )
                    if score > best_score:
                        best_score = score
                        best_error_variance = error_variance
                        best_feature = feature
                        best_labels = self.N_cluster_label
                        best_N_cluster_size = self.N_cluster_size
                        best_n_clusters = n_clusters
                        best_n_cluster_size = self.n_cluster_size

                if best_feature is not None:
                    current_features.append(best_feature)
                    num_of_features = len(current_features)
                    print(
                        "num_of_features:",
                        num_of_features,
                        "current_features:",
                        current_features,
                        ", score:",
                        best_score,
                        "best_n_clusters:",
                        best_n_clusters,
                        "best_N_cluster_size:",
                        best_N_cluster_size,
                        "best_n_cluster_size:",
                        best_n_cluster_size,
                    )

                    features_score_dict[str(num_of_features)] = best_score  # 確認用
                    features_error_variance_dict[str(num_of_features)] = (
                        best_error_variance
                    )

                    remaining_features.remove(best_feature)
                    self.selected_features_ = current_features
                else:
                    break

            self.final_cluster_assignments_dict[allocation_method] = best_labels
            self.final_n_clusters_dict[allocation_method] = best_n_clusters
            self.final_selected_features_dict[allocation_method] = (
                self.selected_features_
            )
            self.features_score_dict_dict[allocation_method] = features_score_dict
            self.features_error_variance_dict_dict[allocation_method] = (
                features_error_variance_dict
            )
            self.final_score_dict[allocation_method] = best_score
            self.final_error_variance_dict[allocation_method] = best_error_variance

        return self

    def crit(self, X: pd.DataFrame, y: pd.DataFrame, allocation_method: str) -> float:
        # クラスタリング手法がGMMの場合
        if self.clustering_method == "gmm":
            model = GaussianMixture(
                n_components=self.n_clusters,
                random_state=self.random_state,
                init_params="kmeans",
            )
        # クラスタリング手法がKMEANSの場合
        if self.clustering_method == "kmeans":
            model = KMeans(
                n_clusters=self.n_clusters,
                random_state=self.random_state,
            )
        if self.clustering_method == "xmeans":
            model = self.xmeans(X)

        model.fit(X)
        self.N_cluster_label = model.predict(X)
        self.N_cluster_size = np.bincount(self.N_cluster_label)
        n_clusters = len(np.unique(self.N_cluster_label))

        error_variance_reduction_rate, error_variance = self.cauculate_reduction_rate(
            X, y, allocation_method
        )
        score = error_variance_reduction_rate

        return score, error_variance, n_clusters

    def compute_bic(self, X: pd.DataFrame, kmeans):
        # クラスタリング結果の取得
        labels = kmeans.labels_
        clusters = kmeans.cluster_centers_
        n_clusters = len(clusters)
        n = len(X)
        m = X.shape[1]
        # クラスター内の分散の合計
        variance = np.sum(
            [
                np.linalg.norm(X[labels == i] - clusters[i], axis=1).sum()
                for i in range(n_clusters)
            ]
        )
        # BIC の計算
        bic = np.log(n) * n_clusters * m + n * np.log(variance / n)
        return bic

    def xmeans(self, X: pd.DataFrame):
        kmeans = KMeans(
            n_clusters=self.k_min, random_state=self.random_state
        )  # 初期クラスター数で KMeans を実行
        kmeans.fit(X)
        best_bic = self.compute_bic(X, kmeans)
        best_kmeans = kmeans
        for k in range(self.k_min + 1, self.k_max + 1):
            kmeans = KMeans(n_clusters=k, random_state=self.random_state)
            kmeans.fit(X)
            # BIC を計算
            current_bic = self.compute_bic(X, kmeans)
            # BIC が改善される場合、クラスタ数を更新
            if current_bic < best_bic:
                best_bic = current_bic
                best_kmeans = kmeans
        # 最適なクラスタリング結果を返す
        return best_kmeans

    def cauculate_reduction_rate(
        self, X: pd.DataFrame, y: pd.DataFrame, allocation_method: str
    ) -> float:
        # 各戦略の標本数に基づいて目的変数の平均を推定
        y_hats = []
        for random_state in range(
            self.exp_num * self.n_trials, (self.exp_num + 1) * self.n_trials
        ):
            np.random.seed(random_state)
            if allocation_method == "Post":
                y_hat = self.estimate_y_mean_post(X, y)
            else:
                y_hat = self.estimate_y_mean_other(X, y, allocation_method)
            y_hats.append(
                {
                    "policy": allocation_method,
                    "y_hat": y_hat,
                    "random_state": random_state,
                }
            )

        y_hat_df = pd.DataFrame(y_hats)
        y_hat_df["error"] = (
            y_hat_df["y_hat"] - y.mean()
        )  # 真の平均からの誤差をerrorカラムに追加

        non_random_allocation_std = y_hat_df["error"].var()
        print("non_random_alloccation_std", non_random_allocation_std)

        # 削減率
        reduction_rate = (
            1 - non_random_allocation_std / self.random_allocation_std
        ) * 100

        return reduction_rate, non_random_allocation_std

    def estimate_y_mean_post(self, X: pd.DataFrame, y: pd.DataFrame) -> float:
        n_cluster_size = np.array([self.sample_size])
        weights = self.N_cluster_size / self.N_cluster_size.sum()
        y_hat = 0
        indices = np.arange(self.N_cluster_size.sum())
        y_array = np.array(y.tolist())
        n_indices = np.random.choice(indices, n_cluster_size[0], replace=False)
        n_label = np.array([self.N_cluster_label[i] for i in n_indices])
        n_new_labels = np.unique(n_label)
        self.n_cluster_size = np.bincount(n_label)
        for h in n_new_labels:
            index = np.where(n_label == h)[0]
            sample = y_array[n_indices[index]]
            y_sample_mean = sample.mean()  # サンプリングした標本の平均
            y_hat += y_sample_mean * weights[h]
        return y_hat

    def estimate_y_mean_other(
        self, X: pd.DataFrame, y: pd.DataFrame, allocation_method: str
    ) -> float:
        if allocation_method == "Proportional":
            self.n_cluster_size = self.ProportionalAllocation(X, y)
        if allocation_method == "Optimal":
            self.n_cluster_size = self.OptimalAllocation(X, y)

        weights = self.N_cluster_size / self.N_cluster_size.sum()
        y_hat = 0
        for h in range(self.n_cluster_size.shape[0]):
            if self.n_cluster_size[h] != 0:
                y_cluster = y[self.N_cluster_label == h]
                if self.n_cluster_size[h] <= len(y_cluster):
                    sample: NDArray = np.random.choice(
                        y_cluster, self.n_cluster_size[h], replace=False
                    )
                    y_sample_mean = sample.mean()  # サンプリングした標本の平均
                    y_hat += y_sample_mean * weights[h]
        return y_hat

    def ProportionalAllocation(self, X: pd.DataFrame, y: pd.DataFrame) -> NDArray:
        n_cluster_size: NDArray = np.round(
            self.N_cluster_size / self.N_cluster_size.sum() * self.sample_size
        ).astype(int)

        if n_cluster_size.sum() > self.sample_size:
            # nの合計がn_samplesより大きい場合は一番標本数が多いクラスタから削る
            n_cluster_size[np.argmax(n_cluster_size)] -= (
                n_cluster_size.sum() - self.sample_size
            )
        if n_cluster_size.sum() < self.sample_size:
            # nの合計がn_samplesより小さい場合は一番標本数が多いクラスタにたす
            n_cluster_size[np.argmax(n_cluster_size)] += (
                -n_cluster_size.sum() + self.sample_size
            )
        return n_cluster_size

    def OptimalAllocation(
        self, X: pd.DataFrame, y: pd.DataFrame
    ) -> NDArray:  # たぶんあってる
        n_cluster = len(np.unique(self.N_cluster_label))
        self.m = np.full(n_cluster, self.m_value)
        # S:クラスタ毎の目的変数のvarianceを要素とする配列 (H, )
        S = np.array([np.var(y[self.N_cluster_label == h]) for h in range(n_cluster)])
        d = (self.N_cluster_size**2) * S

        n_cluster_size = self.m.copy()  # 初期値

        M = self.M.copy() if self.M is not None else self.N_cluster_size.copy()
        I = np.arange(n_cluster)  # noqa #クラスタのインデックス   ###############self.n_clusters
        while (n_cluster_size.sum() != self.sample_size) and len(I) != 0:
            delta = np.zeros(n_cluster)  ############self.n_clusters
            delta[I] = (d / (n_cluster_size + 1) - d / n_cluster_size)[I]
            h_star = np.argmin(delta[I])
            h_star = I[h_star]

            if n_cluster_size[h_star] + 1 <= M[h_star]:
                n_cluster_size[h_star] = n_cluster_size[h_star] + 1
            else:
                # Iの要素h_starを削除
                I_ = I.tolist()
                I_ = [i for i in I_ if i != h_star]
                I = np.array(I_)  # noqa

        # 制約チェック
        assert (
            n_cluster_size.sum() <= self.sample_size
        ), f"Total sample size is over than {self.sample_size}"
        assert np.all(
            n_cluster_size >= self.m
        ), "Minimum sample size constraint is not satisfied"
        if self.M is not None:
            assert np.all(
                n_cluster_size <= self.M
            ), "Maximum sample size constraint is not satisfied"

        return n_cluster_size

    def get_final_selected_features_dict(self) -> dict[NDArray]:
        return self.final_selected_features_dict  # 選択された特徴量のインデックス

    def get_final_cluster_assignments(self) -> dict[NDArray]:
        return self.final_cluster_assignments_dict  # 最終的なクラスタリング結果

    def get_final_n_clusters_dict(self) -> dict:
        return self.final_n_clusters_dict

    def get_final_score_dict(self) -> dict:
        return self.final_score_dict

    def get_final_error_variance_dict(self) -> dict:
        return self.final_error_variance_dict

    def get_features_score_dict_dict(self) -> dict[dict]:
        return self.features_score_dict_dict

    def get_features_error_variance_dict_dict(self) -> dict[dict]:
        return self.features_error_variance_dict_dict

# %% [markdown]
# ----------------
# ### 実験

# %%
all_reduction_rate_dict = {}
all_reduction_rate_dict["Random"] = [0 for i in range(N_EXPERIMENT)]
for allocation_method in ALLOCATION_METHODS:
    all_reduction_rate_dict[allocation_method] = []

all_error_variance_dict = {}
all_error_variance_dict["Random"] = RANDOM_STD_LIST
for allocation_method in ALLOCATION_METHODS:
    all_error_variance_dict[allocation_method] = []

features_score_dict_dict_list = []
features_error_variance_dict_dict_list = []

for exp in range(N_EXPERIMENT):
    ins = Allocation_in_Wrapper(
        maximum_features_to_select=MAXIMUM_FEATURES_TO_SELECT,
        n_clusters=N_CLUSTERS,
        clustering_method=CLUSTERING_METHOD,
        allocation_methods=ALLOCATION_METHODS,
        sample_size=SAMPLE_SIZE,
        n_trials=N_TRIALS,
        m_value=m_VALUE,
        random_state=RANDOM_STATE,
        selecting_features=SELECTING_FEATURES,
        k_min=K_MIN,
        k_max=K_MAX,
        random_allocation_std=RANDOM_STD_LIST[exp],
        exp_num=exp,
    )

    ins.fss(X_scaled, y)
    selected_features_index = ins.get_final_selected_features_dict()
    cluster_label = ins.get_final_cluster_assignments()
    cluster_size = np.unique(cluster_label, return_counts=True)[1]
    features_score_dict_dict = ins.get_features_score_dict_dict()
    features_error_variance_dict_dict = ins.get_features_error_variance_dict_dict()
    features_score_dict_dict_list.append(features_score_dict_dict)
    features_error_variance_dict_dict_list.append(features_error_variance_dict_dict)

    final_score_dict = ins.get_final_score_dict()
    final_error_variance_dict = ins.get_final_error_variance_dict()

    for allocation_method in ALLOCATION_METHODS:
        all_reduction_rate_dict[allocation_method].append(
            final_score_dict[allocation_method]
        )
        all_error_variance_dict[allocation_method].append(
            final_error_variance_dict[allocation_method]
        )


mean_reduction_rate_dict = {}
mean_reduction_rate_dict["Random"] = 0
for allocation_method in ALLOCATION_METHODS:
    mean_reduction_rate_dict[allocation_method] = sum(
        all_reduction_rate_dict[allocation_method]
    ) / len(all_reduction_rate_dict[allocation_method])

mean_error_variance_dict = {}
mean_error_variance_dict["Random"] = sum(RANDOM_STD_LIST) / N_EXPERIMENT
for allocation_method in ALLOCATION_METHODS:
    mean_error_variance_dict[allocation_method] = sum(
        all_error_variance_dict[allocation_method]
    ) / len(all_error_variance_dict[allocation_method])
# Out:
# [ Proportional ]
# c:\Users\HaruMomozu\Desktop\momozu\ABtesting\.venv\Lib\site-packages\threadpoolctl.py:1214: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# non_random_alloccation_std 199823.36705252962
# non_random_alloccation_std 208448.6012915063
# c:\Users\HaruMomozu\Desktop\momozu\ABtesting\.venv\Lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# non_random_alloccation_std 219786.0843458313
# non_random_alloccation_std 193075.7908482504
# non_random_alloccation_std 194039.16344923628
# non_random_alloccation_std 190119.72048904625
# non_random_alloccation_std 217526.74794066683
# non_random_alloccation_std 226189.4643487793
# non_random_alloccation_std 230206.27108113325
# non_random_alloccation_std 223250.81825040327
# non_random_alloccation_std 232604.42115958995
# non_random_alloccation_std 231151.1909778301
# non_random_alloccation_std 213358.8081770097
# non_random_alloccation_std 229242.65751028428
# non_random_alloccation_std 212049.62138141986
# non_random_alloccation_std 216760.18392926405
# non_random_alloccation_std 219808.0580242425
# num_of_features: 1 current_features: [5] , score: 18.206094255356508 best_n_clusters: 10 best_N_cluster_size: [61383   472  3373     3    10   143 23322  1294    55  9027] best_n_cluster_size: [63  0  3  0  0  0 24  1  0  9]
# non_random_alloccation_std 198072.7931572616
# non_random_alloccation_std 181662.0922308986
# non_random_alloccation_std 189668.17365660978
# non_random_alloccation_std 183628.99031060716
# non_random_alloccation_std 183796.48718007907
# non_random_alloccation_std 193411.67578497648
# non_random_alloccation_std 194602.4871000102
# non_random_alloccation_std 190400.6161777558
# non_random_alloccation_std 193234.0459861239
# non_random_alloccation_std 195894.97107638392
# non_random_alloccation_std 188145.5831627866
# non_random_alloccation_std 203655.9706108982
# non_random_alloccation_std 189728.48564111633
# non_random_alloccation_std 190297.30305692056
# non_random_alloccation_std 189611.12363095532
# non_random_alloccation_std 185497.66187471262
# num_of_features: 2 current_features: [5, 1] , score: 21.844761758078935 best_n_clusters: 10 best_N_cluster_size: [75484  2000   109    19   655     5   268  3572     2 16968] best_n_cluster_size: [76  2  0  0  1  0  0  4  0 17]
# non_random_alloccation_std 191887.36672583944
# non_random_alloccation_std 191388.26535012692
# non_random_alloccation_std 183727.50697004652
# non_random_alloccation_std 185948.27201496414
# non_random_alloccation_std 195189.08429670596
# non_random_alloccation_std 201044.82645147972
# non_random_alloccation_std 192560.77494020495
# non_random_alloccation_std 188057.01041373154
# non_random_alloccation_std 192236.6688004468
# non_random_alloccation_std 195514.25554846367
# non_random_alloccation_std 198106.38388755647
# non_random_alloccation_std 190187.5525169466
# non_random_alloccation_std 184772.11613826285
# non_random_alloccation_std 194875.8382099179
# non_random_alloccation_std 189624.89255942445
# num_of_features: 3 current_features: [5, 1, 3] , score: 20.956172515138217 best_n_clusters: 10 best_N_cluster_size: [29786  3711    99 12858    18   552   615  3772     5 47666] best_n_cluster_size: [30  4  0 13  0  1  1  4  0 47]
# non_random_alloccation_std 189323.6801980929
# non_random_alloccation_std 192017.36195726157
# non_random_alloccation_std 185831.49097370743
# non_random_alloccation_std 181052.73110526215
# non_random_alloccation_std 186330.21673874694
# non_random_alloccation_std 187373.64667896382
# non_random_alloccation_std 192679.20514624813
# non_random_alloccation_std 187078.4717947403
# non_random_alloccation_std 190245.7563170607
# non_random_alloccation_std 193047.34841988154
# non_random_alloccation_std 200878.39913354194
# non_random_alloccation_std 182925.3535704509
# non_random_alloccation_std 186332.06871953042
# non_random_alloccation_std 190065.95019342832
# num_of_features: 4 current_features: [5, 1, 3, 6] , score: 22.10692302334141 best_n_clusters: 10 best_N_cluster_size: [36410  2760 23515    60 21596   458   305 10827     4  3147] best_n_cluster_size: [37  3 24  0 22  0  0 11  0  3]
# non_random_alloccation_std 180734.72639790105
# non_random_alloccation_std 188754.97066907806
# non_random_alloccation_std 186602.77195923132
# non_random_alloccation_std 194698.66524518855
# non_random_alloccation_std 178180.6013054339
# non_random_alloccation_std 196148.99151584314
# non_random_alloccation_std 186697.77781489096
# non_random_alloccation_std 191069.95113717418
# non_random_alloccation_std 196315.36059510792
# non_random_alloccation_std 189193.43726454268
# non_random_alloccation_std 178122.6331609242
# non_random_alloccation_std 180171.1678367469
# non_random_alloccation_std 189619.35229927042
# num_of_features: 5 current_features: [5, 1, 3, 6, 14] , score: 23.36751900183992 best_n_clusters: 10 best_N_cluster_size: [15297  1537 30127 20729   138  3790 11136 15908    11   409] best_n_cluster_size: [15  2 31 21  0  4 11 16  0  0]
# non_random_alloccation_std 182492.4570020627
# non_random_alloccation_std 196003.04695392083
# non_random_alloccation_std 187976.7234312257
# non_random_alloccation_std 187665.60413023338
# non_random_alloccation_std 193685.62237774837
# non_random_alloccation_std 196402.06617203818
# non_random_alloccation_std 190122.73009959835
# non_random_alloccation_std 197090.84239681842
# non_random_alloccation_std 197947.03578752006
# non_random_alloccation_std 202801.44440484952
# non_random_alloccation_std 192179.7177348168
# non_random_alloccation_std 198645.1863451459
# num_of_features: 6 current_features: [5, 1, 3, 6, 14, 0] , score: 21.487519607440575 best_n_clusters: 10 best_N_cluster_size: [15936   420 29215 20300 11179 16911    37   703   329  4052] best_n_cluster_size: [16  0 31 20 11 17  0  1  0  4]
# non_random_alloccation_std 187490.0684089016
# non_random_alloccation_std 188605.2638009904
# non_random_alloccation_std 198613.43835760735
# non_random_alloccation_std 188062.79990930084
# non_random_alloccation_std 188019.84564126763
# non_random_alloccation_std 184225.93281844186
# non_random_alloccation_std 195152.34098269808
# non_random_alloccation_std 184293.48045204137
# non_random_alloccation_std 196427.88734685993
# non_random_alloccation_std 191439.6742370656
# non_random_alloccation_std 192586.614852719
# num_of_features: 7 current_features: [5, 1, 3, 6, 14, 0, 10] , score: 20.741738174715906 best_n_clusters: 10 best_N_cluster_size: [14369  9309 14044   941 13643 25333   354    54  3475 17560] best_n_cluster_size: [15  9 14  1 14 25  0  0  4 18]
# non_random_alloccation_std 189834.8006473599
# non_random_alloccation_std 190547.48683602005
# non_random_alloccation_std 193438.5946188313
# non_random_alloccation_std 195787.646247515
# non_random_alloccation_std 188761.48897424704
# non_random_alloccation_std 197882.4840116595
# non_random_alloccation_std 191868.26252527628
# non_random_alloccation_std 192046.2230631509
# non_random_alloccation_std 192446.5196880115
# non_random_alloccation_std 192276.51117853052
# num_of_features: 8 current_features: [5, 1, 3, 6, 14, 0, 10, 9] , score: 18.790436901217344 best_n_clusters: 10 best_N_cluster_size: [13744 18787  9139    27  1090 20138 34209   471   561   916] best_n_cluster_size: [14 19  9  0  1 20 35  0  1  1]
# non_random_alloccation_std 199093.84199216677
# non_random_alloccation_std 192270.90423575861
# non_random_alloccation_std 193023.2791083905
# non_random_alloccation_std 195542.47045181063
# non_random_alloccation_std 199264.35566514207
# non_random_alloccation_std 200128.8873927938
# non_random_alloccation_std 189839.73149738123
# non_random_alloccation_std 197116.07675166588
# non_random_alloccation_std 195270.8366103455
# num_of_features: 9 current_features: [5, 1, 3, 6, 14, 0, 10, 9, 13] , score: 18.32655200237443 best_n_clusters: 10 best_N_cluster_size: [12462 13658 24811 18208  1612 17996   108   236  1992  7999] best_n_cluster_size: [13 14 25 18  2 18  0  0  2  8]
# non_random_alloccation_std 197492.16306544282
# non_random_alloccation_std 198619.47897404133
# non_random_alloccation_std 186783.44470399583
# non_random_alloccation_std 192544.30501707594
# non_random_alloccation_std 197718.84211709828
# non_random_alloccation_std 200946.40286052527
# non_random_alloccation_std 202705.02795739222
# non_random_alloccation_std 195946.2856968852
# num_of_features: 10 current_features: [5, 1, 3, 6, 14, 0, 10, 9, 13, 7] , score: 19.64143734548205 best_n_clusters: 10 best_N_cluster_size: [ 7929 14510 29574   443 17714   177  2950  5457 17438  2890] best_n_cluster_size: [ 8 15 29  0 18  0  3  6 18  3]
# non_random_alloccation_std 195804.52941788998
# non_random_alloccation_std 206163.26524634782
# non_random_alloccation_std 191409.64507308486
# non_random_alloccation_std 189161.2229768404
# non_random_alloccation_std 195798.18605059557
# non_random_alloccation_std 187485.71114095487
# non_random_alloccation_std 202536.95310179138
# num_of_features: 11 current_features: [5, 1, 3, 6, 14, 0, 10, 9, 13, 7, 15] , score: 19.339306064179418 best_n_clusters: 10 best_N_cluster_size: [10415 33878 17981   432 19382   197  3731  1372   435 11259] best_n_cluster_size: [11 35 18  0 20  0  4  1  0 11]
# non_random_alloccation_std 196224.20669397077
# non_random_alloccation_std 191986.23752079406
# non_random_alloccation_std 191168.6087335488
# non_random_alloccation_std 186801.33879479242
# non_random_alloccation_std 191664.71901063985
# non_random_alloccation_std 200588.25718771093
# num_of_features: 12 current_features: [5, 1, 3, 6, 14, 0, 10, 9, 13, 7, 15, 11] , score: 19.63373889330551 best_n_clusters: 10 best_N_cluster_size: [11067 17784 18847  3352 13710  4645 28515   471   339   352] best_n_cluster_size: [11 18 19  3 14  5 30  0  0  0]
# non_random_alloccation_std 194875.24284380188
# non_random_alloccation_std 189605.71431119993
# non_random_alloccation_std 191757.96568057008
# non_random_alloccation_std 193151.02143367313
# non_random_alloccation_std 192518.31697854254
# num_of_features: 13 current_features: [5, 1, 3, 6, 14, 0, 10, 9, 13, 7, 15, 11, 4] , score: 18.42723161425216 best_n_clusters: 10 best_N_cluster_size: [ 4993 17217 12849   306 17127   457  1781  3175 30799 10378] best_n_cluster_size: [ 5 17 13  0 17  0  2  3 33 10]
# non_random_alloccation_std 200144.59590262777
# non_random_alloccation_std 192360.54540263163
# non_random_alloccation_std 195227.0794466637
# non_random_alloccation_std 196299.4190301424
# num_of_features: 14 current_features: [5, 1, 3, 6, 14, 0, 10, 9, 13, 7, 15, 11, 4, 8] , score: 17.242039493964146 best_n_clusters: 10 best_N_cluster_size: [11032 17810 31680  3204 13377   580  2617   313   268 18201] best_n_cluster_size: [11 18 32  3 14  1  3  0  0 18]
# non_random_alloccation_std 191774.28663341014
# non_random_alloccation_std 191374.36219518873
# non_random_alloccation_std 200079.8012814378
# num_of_features: 15 current_features: [5, 1, 3, 6, 14, 0, 10, 9, 13, 7, 15, 11, 4, 8, 12] , score: 17.66631834367548 best_n_clusters: 10 best_N_cluster_size: [10922 17785 33444  3285  1878   267 18239   584 12566   112] best_n_cluster_size: [11 18 34  3  2  0 18  1 13  0]
# non_random_alloccation_std 186248.09579588653
# non_random_alloccation_std 195718.21053039367
# num_of_features: 16 current_features: [5, 1, 3, 6, 14, 0, 10, 9, 13, 7, 15, 11, 4, 8, 12, 2] , score: 19.871756841101718 best_n_clusters: 10 best_N_cluster_size: [10155 15732 27269   312  1998 12902  3605  1559 10955 14595] best_n_cluster_size: [10 16 27  0  2 13  4  2 11 15]
# non_random_alloccation_std 203248.16304364946
# num_of_features: 17 current_features: [5, 1, 3, 6, 14, 0, 10, 9, 13, 7, 15, 11, 4, 8, 12, 2, 16] , score: 12.557934295290451 best_n_clusters: 10 best_N_cluster_size: [ 9946 11433 25383   835  9983 28676  2013  3919   275  6619] best_n_cluster_size: [10 12 26  1 10 28  2  4  0  7]
# [ Post ]
# non_random_alloccation_std 212573.8992601422
# non_random_alloccation_std 208316.59149904305
# c:\Users\HaruMomozu\Desktop\momozu\ABtesting\.venv\Lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# non_random_alloccation_std 222726.81636021484
# non_random_alloccation_std 208701.21614452754
# non_random_alloccation_std 202607.6305516913
# non_random_alloccation_std 192980.43839724144
# non_random_alloccation_std 237404.05772081134
# non_random_alloccation_std 230392.92774328167
# non_random_alloccation_std 226658.36676294368
# non_random_alloccation_std 223715.23328591557
# non_random_alloccation_std 231461.85199095204
# non_random_alloccation_std 243506.52249123843
# non_random_alloccation_std 223952.8230888015
# non_random_alloccation_std 244971.11587286764
# non_random_alloccation_std 241183.2842424938
# non_random_alloccation_std 224427.13310615096
# non_random_alloccation_std 226439.35102403673
# num_of_features: 1 current_features: [5] , score: 16.975347174816747 best_n_clusters: 10 best_N_cluster_size: [61383   472  3373     3    10   143 23322  1294    55  9027] best_n_cluster_size: [63  0  4  0  0  0 21  3  0  9]
# non_random_alloccation_std 205921.55003134857
# non_random_alloccation_std 197702.14563594435
# non_random_alloccation_std 201401.5454863639
# non_random_alloccation_std 196548.6525378499
# non_random_alloccation_std 193418.72573753222
# non_random_alloccation_std 200433.35521604202
# non_random_alloccation_std 205450.37359763484
# non_random_alloccation_std 202168.092779996
# non_random_alloccation_std 201225.8912075738
# non_random_alloccation_std 203576.51630268845
# non_random_alloccation_std 205356.9886991789
# non_random_alloccation_std 199516.17227784966
# non_random_alloccation_std 201275.95071253605
# non_random_alloccation_std 205768.64089385202
# non_random_alloccation_std 200550.9183540306
# non_random_alloccation_std 195848.98898341574
# num_of_features: 2 current_features: [5, 4] , score: 16.786785813014827 best_n_clusters: 10 best_N_cluster_size: [57550  2351    57   699  3872   114  7727    12 26182   518] best_n_cluster_size: [57  3  0  1  8  0  4  0 27]
# non_random_alloccation_std 200699.42654805083
# non_random_alloccation_std 196122.32330284422
# non_random_alloccation_std 194431.02903115103
# non_random_alloccation_std 197901.01645255045
# non_random_alloccation_std 198531.76398595623
# non_random_alloccation_std 202092.3214308035
# non_random_alloccation_std 203220.6065648345
# non_random_alloccation_std 195155.85062651808
# non_random_alloccation_std 199681.36968147504
# non_random_alloccation_std 206025.35820893373
# non_random_alloccation_std 199776.6714096903
# non_random_alloccation_std 201769.88703727594
# non_random_alloccation_std 198077.56237136593
# non_random_alloccation_std 199983.50028669517
# non_random_alloccation_std 202955.48411844537
# num_of_features: 3 current_features: [5, 4, 2] , score: 16.35126949745186 best_n_clusters: 10 best_N_cluster_size: [38778 11983 34874  1008   241     8  7982   120  2328  1760] best_n_cluster_size: [37  6 39  1  0  0 10  0  3  4]
# non_random_alloccation_std 201297.18863094665
# non_random_alloccation_std 192086.96720328717
# non_random_alloccation_std 197561.1914474393
# non_random_alloccation_std 198465.39642004113
# non_random_alloccation_std 201645.32929771353
# non_random_alloccation_std 200145.63830973738
# non_random_alloccation_std 197932.28707937084
# non_random_alloccation_std 199485.7701074332
# non_random_alloccation_std 209855.2539047583
# non_random_alloccation_std 200329.24692992252
# non_random_alloccation_std 205971.05631344428
# non_random_alloccation_std 204672.68287747138
# non_random_alloccation_std 195830.0706806002
# non_random_alloccation_std 200052.0670032302
# num_of_features: 4 current_features: [5, 4, 2, 1] , score: 17.359739169691668 best_n_clusters: 10 best_N_cluster_size: [48272 35440   595 10592   175   179  1941    42     9  1837] best_n_cluster_size: [49 38  2  7  0  0  3  0  0  1]
# non_random_alloccation_std 189673.05595672975
# non_random_alloccation_std 199277.56732853464
# non_random_alloccation_std 202772.14160579143
# non_random_alloccation_std 203061.03059421186
# non_random_alloccation_std 195152.99342599654
# non_random_alloccation_std 194218.50919430566
# non_random_alloccation_std 201315.53393450452
# non_random_alloccation_std 204102.14464670166
# non_random_alloccation_std 191884.97915747427
# non_random_alloccation_std 203960.94756299077
# non_random_alloccation_std 204581.99292240952
# non_random_alloccation_std 192849.9011560906
# non_random_alloccation_std 198892.24846259184
# num_of_features: 5 current_features: [5, 4, 2, 1, 0] , score: 18.398259679131556 best_n_clusters: 10 best_N_cluster_size: [48290 13135   573  1135   774 31301    14    80    98  3682] best_n_cluster_size: [50 12  0  3  0 31  0  0  0  4]
# non_random_alloccation_std 195595.97159231073
# non_random_alloccation_std 199037.7212913319
# non_random_alloccation_std 200935.88909446806
# non_random_alloccation_std 194453.92987298308
# non_random_alloccation_std 192848.11806701907
# non_random_alloccation_std 199332.20034982567
# non_random_alloccation_std 203057.84951015172
# non_random_alloccation_std 196898.16121405596
# non_random_alloccation_std 201040.76265760942
# non_random_alloccation_std 197911.07819932041
# non_random_alloccation_std 194211.4704703918
# non_random_alloccation_std 198058.9307299738
# num_of_features: 6 current_features: [5, 4, 2, 1, 0, 9] , score: 17.032274444594275 best_n_clusters: 10 best_N_cluster_size: [47540  1446  6939   551 39655   235  2061    18   106   531] best_n_cluster_size: [51  1  5  0 40  0  3]
# non_random_alloccation_std 197179.92040996073
# non_random_alloccation_std 194708.14154504726
# non_random_alloccation_std 198652.85945272638
# non_random_alloccation_std 203338.93126402536
# non_random_alloccation_std 204099.07465234573
# non_random_alloccation_std 206533.74848223492
# non_random_alloccation_std 194809.6476737561
# non_random_alloccation_std 208856.18709855154
# non_random_alloccation_std 204997.77657542092
# non_random_alloccation_std 194882.49623508888
# non_random_alloccation_std 198753.0631657941
# num_of_features: 7 current_features: [5, 4, 2, 1, 0, 9, 6] , score: 16.23204927777142 best_n_clusters: 10 best_N_cluster_size: [47675 11488   201   226   501  1918 34433  2228    27   385] best_n_cluster_size: [51 11  0  0  0  3 33  2]
# non_random_alloccation_std 198208.66078585785
# non_random_alloccation_std 201965.0571111907
# non_random_alloccation_std 200466.61001558448
# non_random_alloccation_std 214782.5972490365
# non_random_alloccation_std 206503.63296708427
# non_random_alloccation_std 196364.64505096295
# non_random_alloccation_std 206724.8572280121
# non_random_alloccation_std 202680.6282132364
# non_random_alloccation_std 206897.9459857254
# non_random_alloccation_std 201989.56920101173
# num_of_features: 8 current_features: [5, 4, 2, 1, 0, 9, 6, 12] , score: 15.519383115208097 best_n_clusters: 10 best_N_cluster_size: [26724 36332   119   119  1001  1590    55 10505 21378  1259] best_n_cluster_size: [35 36  0  0  0  1  0 10 16  2]
# non_random_alloccation_std 200884.3088779301
# non_random_alloccation_std 198480.66035556904
# non_random_alloccation_std 200575.45956128897
# non_random_alloccation_std 205844.0317948728
# non_random_alloccation_std 205256.75061720738
# non_random_alloccation_std 206941.06608220175
# non_random_alloccation_std 202736.8231329759
# non_random_alloccation_std 200837.09624014338
# non_random_alloccation_std 198194.50693366173
# num_of_features: 9 current_features: [5, 4, 2, 1, 0, 9, 6, 12, 16] , score: 14.732134165050903 best_n_clusters: 10 best_N_cluster_size: [43097 37674  6826  7507  1063   223  1921    55   596   120] best_n_cluster_size: [45 39  7  6  0  0  3]
# non_random_alloccation_std 198903.99570600165
# non_random_alloccation_std 205899.93699457592
# non_random_alloccation_std 201454.51548399625
# non_random_alloccation_std 212417.46021980594
# non_random_alloccation_std 220083.74894446915
# non_random_alloccation_std 218278.4188125791
# non_random_alloccation_std 206038.12746365406
# non_random_alloccation_std 201611.16260678097
# num_of_features: 10 current_features: [5, 4, 2, 1, 0, 9, 6, 12, 16, 3] , score: 14.426895667843054 best_n_clusters: 10 best_N_cluster_size: [24849 10790 34564    64  6601 18641  1149  1152   119  1153] best_n_cluster_size: [31  9 38  0  7 13  0  2]
# non_random_alloccation_std 206504.91720994317
# non_random_alloccation_std 203550.88735088796
# non_random_alloccation_std 199679.3735343884
# non_random_alloccation_std 206797.9571667667
# non_random_alloccation_std 204275.1197913679
# non_random_alloccation_std 202607.28432141984
# non_random_alloccation_std 203364.08389949225
# num_of_features: 11 current_features: [5, 4, 2, 1, 0, 9, 6, 12, 16, 3, 10] , score: 14.093310173143115 best_n_clusters: 10 best_N_cluster_size: [12595  1131 36396  9925  1040  6676    64  1075 30080   100] best_n_cluster_size: [14  0 37  9  0  7  0  2 31]
# non_random_alloccation_std 214952.14324803132
# non_random_alloccation_std 206342.55904625144
# non_random_alloccation_std 208973.46486766898
# non_random_alloccation_std 201297.95172182802
# non_random_alloccation_std 208168.09733730607
# non_random_alloccation_std 205721.8591811709
# num_of_features: 12 current_features: [5, 4, 2, 1, 0, 9, 6, 12, 16, 3, 10, 13] , score: 13.396960360702693 best_n_clusters: 10 best_N_cluster_size: [12184 29951  9926  6534 25400  1050  1044    55 11911  1027] best_n_cluster_size: [11 33 10  7 26  1  0  0 12]
# non_random_alloccation_std 213459.2093835514
# non_random_alloccation_std 208447.84012059218
# non_random_alloccation_std 227230.69591985297
# non_random_alloccation_std 203556.56533782984
# non_random_alloccation_std 222452.45167340126
# num_of_features: 13 current_features: [5, 4, 2, 1, 0, 9, 6, 12, 16, 3, 10, 13, 14] , score: 12.425252487655058 best_n_clusters: 10 best_N_cluster_size: [12046 14092 20199 33927  1098   303  6854  9403  1057   103] best_n_cluster_size: [ 9 16 24 34  0  0  7  8  2]
# non_random_alloccation_std 214509.65910180807
# non_random_alloccation_std 215693.07106188714
# non_random_alloccation_std 225558.10410948435
# non_random_alloccation_std 211426.62349908563
# num_of_features: 14 current_features: [5, 4, 2, 1, 0, 9, 6, 12, 16, 3, 10, 13, 14, 15] , score: 9.039371245084505 best_n_clusters: 10 best_N_cluster_size: [ 6718 24614   976 11237 29672 11252  6736  7364   105   408] best_n_cluster_size: [ 8 25  0 12 30 11  7  7]
# non_random_alloccation_std 205328.65755088595
# non_random_alloccation_std 207738.64167813965
# non_random_alloccation_std 209261.65362262304
# num_of_features: 15 current_features: [5, 4, 2, 1, 0, 9, 6, 12, 16, 3, 10, 13, 14, 15, 7] , score: 11.662857386964397 best_n_clusters: 10 best_N_cluster_size: [11329  1013 35476 26426  2427  6820    57  1567 13869    98] best_n_cluster_size: [10  0 37 30  4  7  0  1 11]
# non_random_alloccation_std 210552.62902721355
# non_random_alloccation_std 228758.9849395831
# num_of_features: 16 current_features: [5, 4, 2, 1, 0, 9, 6, 12, 16, 3, 10, 13, 14, 15, 7, 8] , score: 9.415383903159935 best_n_clusters: 10 best_N_cluster_size: [14033 29841 22875 10586  3172 10323  6588   789   553   322] best_n_cluster_size: [14 30 23 10  3 12  7  0  1]
# non_random_alloccation_std 215858.71582569386
# num_of_features: 17 current_features: [5, 4, 2, 1, 0, 9, 6, 12, 16, 3, 10, 13, 14, 15, 7, 8, 11] , score: 7.132582506485252 best_n_clusters: 10 best_N_cluster_size: [ 9946 11433 25383   835  9983 28676  2013  3919   275  6619] best_n_cluster_size: [ 8 13 27  0  9 27  3  6  0  7]
# [ Optimal ]
# non_random_alloccation_std 201233.72027772712
# non_random_alloccation_std 204004.75702898062
# c:\Users\HaruMomozu\Desktop\momozu\ABtesting\.venv\Lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# non_random_alloccation_std 212188.2243053683
# non_random_alloccation_std 176868.04017110053
# non_random_alloccation_std 180466.27796801573
# non_random_alloccation_std 159970.51985721552
# non_random_alloccation_std 205266.97273521908
# non_random_alloccation_std 230157.37521023917
# non_random_alloccation_std 254571.14854919608
# non_random_alloccation_std 251432.60367402688
# non_random_alloccation_std 236288.19216507408
# non_random_alloccation_std 226740.96065166828
# non_random_alloccation_std 246666.73819411156
# non_random_alloccation_std 229077.5515915654
# non_random_alloccation_std 194253.2513303024
# non_random_alloccation_std 240156.87094311794
# non_random_alloccation_std 205871.55732242158
# num_of_features: 1 current_features: [5] , score: 31.176978435140423 best_n_clusters: 10 best_N_cluster_size: [61383   472  3373     3    10   143 23322  1294    55  9027] best_n_cluster_size: [39  2  7  2  2  2 25  4  2 15]
# non_random_alloccation_std 179676.36457984927
# non_random_alloccation_std 174142.92423376176
# non_random_alloccation_std 167138.85757099508
# non_random_alloccation_std 166703.6194060246
# non_random_alloccation_std 169930.32823836672
# non_random_alloccation_std 176085.0814187695
# non_random_alloccation_std 173559.1375745387
# non_random_alloccation_std 172910.0104141068
# non_random_alloccation_std 172904.38483424095
# non_random_alloccation_std 168416.03814360555
# non_random_alloccation_std 176460.8471197019
# non_random_alloccation_std 182073.79909378456
# non_random_alloccation_std 167708.20688903297
# non_random_alloccation_std 173808.4810500716
# non_random_alloccation_std 172941.17789246797
# non_random_alloccation_std 161312.02146520966
# num_of_features: 2 current_features: [5, 16] , score: 30.599833382547715 best_n_clusters: 10 best_N_cluster_size: [38915  6333  3811   290 11501    60     8 13366  1116 23682] best_n_cluster_size: [33  5  9  2  7  2  2 21  3 16]
# non_random_alloccation_std 182202.71525474175
# non_random_alloccation_std 167761.20628746154
# non_random_alloccation_std 173204.70271005278
# non_random_alloccation_std 175208.7622375067
# non_random_alloccation_std 173732.98625689157
# non_random_alloccation_std 175648.5341601268
# non_random_alloccation_std 170248.61943548758
# non_random_alloccation_std 175458.41381894914
# non_random_alloccation_std 176000.77113613664
# non_random_alloccation_std 176615.74404977448
# non_random_alloccation_std 185687.85995567543
# non_random_alloccation_std 174870.8387107639
# non_random_alloccation_std 183697.33166612708
# non_random_alloccation_std 175804.9156440639
# non_random_alloccation_std 176551.8075902663
# num_of_features: 3 current_features: [5, 16, 1] , score: 27.825244749005897 best_n_clusters: 10 best_N_cluster_size: [43616  6473    23   549    19   258 11347 26961  2493  7343] best_n_cluster_size: [42  5  2  2  2  2  7 18  6 14]
# non_random_alloccation_std 185389.34040110133
# non_random_alloccation_std 189914.8354208105
# non_random_alloccation_std 173750.21487191593
# non_random_alloccation_std 174988.28172843982
# non_random_alloccation_std 184221.9436819729
# non_random_alloccation_std 172167.63586815674
# non_random_alloccation_std 178111.50119451623
# non_random_alloccation_std 172923.7476798329
# non_random_alloccation_std 174941.19937648057
# non_random_alloccation_std 178755.28796869656
# non_random_alloccation_std 191906.9989309356
# non_random_alloccation_std 185732.44118595566
# non_random_alloccation_std 174551.05036112238
# non_random_alloccation_std 192594.5337953972
# num_of_features: 4 current_features: [5, 16, 1, 7] , score: 25.92949671788801 best_n_clusters: 10 best_N_cluster_size: [ 7994   201  7324  3427    22  1801 64467   516 11666  1664] best_n_cluster_size: [ 7  2  5  4  2  5 50  2 21  2]
# non_random_alloccation_std 185446.88855196408
# non_random_alloccation_std 190819.76722724218
# non_random_alloccation_std 171184.83050788043
# non_random_alloccation_std 172423.1282794252
# non_random_alloccation_std 189016.19617817193
# non_random_alloccation_std 186369.96099145527
# non_random_alloccation_std 175492.8551575311
# non_random_alloccation_std 189789.73656607248
# non_random_alloccation_std 194674.50114075723
# non_random_alloccation_std 178748.01129085143
# non_random_alloccation_std 188922.9771124308
# non_random_alloccation_std 191259.40332761765
# non_random_alloccation_std 192963.58949057414
# num_of_features: 5 current_features: [5, 16, 1, 7, 3] , score: 26.352322339538357 best_n_clusters: 10 best_N_cluster_size: [45590  6356  4776  5660    30   647   548 11656 21908  1911] best_n_cluster_size: [37  4  5 11  2  2  2  7 28  2]
# non_random_alloccation_std 179307.9312023027
# non_random_alloccation_std 184651.5097345035
# non_random_alloccation_std 172969.12721633585
# non_random_alloccation_std 181460.11575343186
# non_random_alloccation_std 175433.20433019055
# non_random_alloccation_std 174551.58184358315
# non_random_alloccation_std 172270.31897437986
# non_random_alloccation_std 183634.78124563015
# non_random_alloccation_std 182083.61528227627
# non_random_alloccation_std 174348.1383954904
# non_random_alloccation_std 181317.41230858892
# non_random_alloccation_std 180658.4182976167
# num_of_features: 6 current_features: [5, 16, 1, 7, 3, 10] , score: 25.885320068088735 best_n_clusters: 10 best_N_cluster_size: [12786 19513  3329  6197   830 40462    40 10390  5061   474] best_n_cluster_size: [12 25  4  4  2 33  2  6 10  2]
# non_random_alloccation_std 178016.90534709572
# non_random_alloccation_std 190252.67667934514
# non_random_alloccation_std 170979.0597469124
# non_random_alloccation_std 180951.19070288815
# non_random_alloccation_std 181323.935084416
# non_random_alloccation_std 180547.53877317708
# non_random_alloccation_std 178650.54107566233
# non_random_alloccation_std 192560.7200442798
# non_random_alloccation_std 181423.2690832424
# non_random_alloccation_std 179635.57375525942
# non_random_alloccation_std 188719.46521197236
# num_of_features: 7 current_features: [5, 16, 1, 7, 3, 10, 4] , score: 26.440849685277822 best_n_clusters: 10 best_N_cluster_size: [12539 40537 19175   633 10510  3316  6249    38   828  5257] best_n_cluster_size: [12 33 25  2  6  4  4  2  2 10]
# non_random_alloccation_std 171931.71254888465
# non_random_alloccation_std 180900.7239839916
# non_random_alloccation_std 179773.64748762484
# non_random_alloccation_std 176869.6121398993
# non_random_alloccation_std 177524.9340041847
# non_random_alloccation_std 177080.6836756966
# non_random_alloccation_std 181927.47546760092
# non_random_alloccation_std 189448.09123223877
# non_random_alloccation_std 176870.8986257245
# non_random_alloccation_std 176243.29221279745
# num_of_features: 8 current_features: [5, 16, 1, 7, 3, 10, 4, 0] , score: 26.030996392355586 best_n_clusters: 10 best_N_cluster_size: [10516 20384  4992  7010   489   960  4033 48948    55  1695] best_n_cluster_size: [ 9 26  9  5  2  3  4 38  2  2]
# non_random_alloccation_std 182267.89170700352
# non_random_alloccation_std 186174.374141498
# non_random_alloccation_std 180471.80761668726
# non_random_alloccation_std 180183.877116118
# non_random_alloccation_std 175345.32980458828
# non_random_alloccation_std 182401.37123653758
# non_random_alloccation_std 179447.9952361747
# non_random_alloccation_std 172101.49243547677
# non_random_alloccation_std 178739.13994003623
# num_of_features: 9 current_features: [5, 16, 1, 7, 3, 10, 4, 0, 14] , score: 25.957953154097446 best_n_clusters: 10 best_N_cluster_size: [12042 23088 37042   927   401  3187  6917  3342    53 12083] best_n_cluster_size: [11 24 26  2  2  4  5  7  2 17]
# non_random_alloccation_std 173934.98866025123
# non_random_alloccation_std 183278.34720055075
# non_random_alloccation_std 178415.36242651855
# non_random_alloccation_std 174660.41186955443
# non_random_alloccation_std 178761.28406918643
# non_random_alloccation_std 178165.43884139866
# non_random_alloccation_std 181313.739005572
# non_random_alloccation_std 184757.69646061206
# num_of_features: 10 current_features: [5, 16, 1, 7, 3, 10, 4, 0, 14, 2] , score: 25.169140625830543 best_n_clusters: 10 best_N_cluster_size: [11169 14468 24793  6677   492  3123   322  4996 21184 11858] best_n_cluster_size: [10 18 17  5  2  4  2 10 18 14]
# non_random_alloccation_std 179382.30849425154
# non_random_alloccation_std 184289.65820686021
# non_random_alloccation_std 188806.70958904404
# non_random_alloccation_std 179096.8394379548
# non_random_alloccation_std 187682.39289194494
# non_random_alloccation_std 181872.80013757412
# non_random_alloccation_std 182495.91094961434
# num_of_features: 11 current_features: [5, 16, 1, 7, 3, 10, 4, 0, 14, 2, 11] , score: 22.94839290490316 best_n_clusters: 10 best_N_cluster_size: [ 5679 24855  1804 33855 12318  3964   313  6664  6905  2725] best_n_cluster_size: [ 6 22  4 29 19  5  2  5  5  3]
# non_random_alloccation_std 184160.49367054744
# non_random_alloccation_std 174615.65152095593
# non_random_alloccation_std 180284.61707507353
# non_random_alloccation_std 174506.29757872055
# non_random_alloccation_std 177970.10753461643
# non_random_alloccation_std 182469.20530630316
# num_of_features: 12 current_features: [5, 16, 1, 7, 3, 10, 4, 0, 14, 2, 11, 12] , score: 24.92335030114381 best_n_clusters: 10 best_N_cluster_size: [10654 26476  6678 23951   308  2990 11985 11811  1428  2801] best_n_cluster_size: [10 24  5 16  2  3 14 18  4  4]
# non_random_alloccation_std 180706.05965463218
# non_random_alloccation_std 182608.6838762479
# non_random_alloccation_std 185336.39579067143
# non_random_alloccation_std 188968.57437353022
# non_random_alloccation_std 184007.62872463753
# num_of_features: 13 current_features: [5, 16, 1, 7, 3, 10, 4, 0, 14, 2, 11, 12, 6] , score: 22.25606910815706 best_n_clusters: 10 best_N_cluster_size: [ 9916   937 28890 15301 20696  9920  2922  3801  6610    89] best_n_cluster_size: [ 9  3 27 10 20 16  3  5  5  2]
# non_random_alloccation_std 184716.77626365228
# non_random_alloccation_std 185718.38490899524
# non_random_alloccation_std 177053.15781598407
# non_random_alloccation_std 178464.52673778211
# num_of_features: 14 current_features: [5, 16, 1, 7, 3, 10, 4, 0, 14, 2, 11, 12, 6, 13] , score: 23.82763205763043 best_n_clusters: 10 best_N_cluster_size: [ 6461 28375 10915   888  6560  9609  2455 24905  5927  2987] best_n_cluster_size: [ 5 27 11  3  5 16  3 20  6  4]
# non_random_alloccation_std 186640.39934717424
# non_random_alloccation_std 185381.46305762598
# non_random_alloccation_std 192030.74304860606
# num_of_features: 15 current_features: [5, 16, 1, 7, 3, 10, 4, 0, 14, 2, 11, 12, 6, 13, 9] , score: 20.244602310925508 best_n_clusters: 10 best_N_cluster_size: [10369  6771 34493  2392 29203   100   561  4882  2558  7753] best_n_cluster_size: [ 9  8 29  3 28  2  2  3  2 14]
# non_random_alloccation_std 185409.19512722798
# non_random_alloccation_std 189436.8803715857
# num_of_features: 16 current_features: [5, 16, 1, 7, 3, 10, 4, 0, 14, 2, 11, 12, 6, 13, 9, 8] , score: 20.23267133248048 best_n_clusters: 10 best_N_cluster_size: [ 9653 28372 25126 10134  6609  2919  3738 11141   917   473] best_n_cluster_size: [ 9 26 20 17  4  3  5 11  3  2]
# non_random_alloccation_std 189806.11211264797
# num_of_features: 17 current_features: [5, 16, 1, 7, 3, 10, 4, 0, 14, 2, 11, 12, 6, 13, 9, 8, 15] , score: 18.341015840102525 best_n_clusters: 10 best_N_cluster_size: [ 9946 11433 25383   835  9983 28676  2013  3919   275  6619] best_n_cluster_size: [ 9 11 20  2 16 27  3  5  2  5]

# %% [markdown]
# ---------------
# ### 可視化

# %% [markdown]
# ##### 誤差分散削減率の推移

# %%
for exp in range(N_EXPERIMENT):
    # グラフ作成
    fig, axs = plt.subplots(
        1, len(ALLOCATION_METHODS), figsize=(8 * len(ALLOCATION_METHODS), 5)
    )  # サブプロットを作成

    plot_idx = 0
    for allocation, dict in features_score_dict_dict_list[exp].items():
        if len(features_score_dict_dict_list[exp]) == 1:
            ax = axs
        else:
            ax = axs[plot_idx]
        bars = ax.bar(dict.keys(), dict.values())
        # for key, value in dict.items():
        #     rounded_value = round(value, 2)
        #     ax.text(key, value + 0.3, str(rounded_value), ha="center", fontsize=18)
        ax.set_title(f"Error variance reduction rate ({allocation})", fontsize=25)
        ax.set_xlabel("Number of features", fontsize=20)
        ax.set_ylabel("Error variance reduction rate", fontsize=20)
        ax.tick_params(axis="both", which="major", labelsize=18)
        ax.set_ylim([0, 40])  # Y軸の範囲を0から20に設定
        plot_idx += 1

    plt.tight_layout()
    plt.show()

    # グラフ作成
    fig, axs = plt.subplots(
        1, len(ALLOCATION_METHODS), figsize=(8 * len(ALLOCATION_METHODS), 5)
    )  # サブプロットを作成

    plot_idx = 0
    for allocation, dict in features_error_variance_dict_dict_list[exp].items():
        if len(features_error_variance_dict_dict_list[exp]) == 1:
            ax = axs
        else:
            ax = axs[plot_idx]
        bars = ax.bar(dict.keys(), dict.values())
        for key, value in dict.items():
            rounded_value = round(value, 2)
            # ax.text(key, value + 10, str(rounded_value), ha="center", fontsize=15)
        random_bar = ax.bar("ran", RANDOM_STD_LIST[exp], color="blue")
        # ax.text("random", random_std + 0.3, str(round(random_std, 2)), ha="center")
        ax.set_title(f"Error variance ({allocation})", fontsize=25)
        ax.set_xlabel("Number of features", fontsize=20)
        ax.set_ylabel("Error variance", fontsize=20)
        ax.tick_params(axis="both", which="major", labelsize=18)
        ax.set_ylim([0, 250000])  # Y軸の範囲を0から20に設定
        plot_idx += 1

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##### 箱ひげ図

# %%
# 誤差分散削減率の箱ひげ図
fig, axs = plt.subplots(1, 1, figsize=(8, 5))  # サブプロットを作成

ax = axs
allo_data = list(all_reduction_rate_dict.values())  # allo1, allo2, allo3 のデータリスト
allo_labels = list(all_reduction_rate_dict.keys())  # alloのラベルリスト
ax.boxplot(allo_data, labels=allo_labels)
# グラフタイトルを設定
ax.set_title(
    f"誤差分散削減率の分布（{CLUSTERING_METHOD_NAME}）",
    fontsize=25,
)
ax.set_ylabel("誤差分散削減率", fontsize=21)
ax.tick_params(axis="both", which="major", labelsize=18)
ax.set_ylim(-10, 35)

# グラフを表示
plt.tight_layout()  # レイアウトを調整
plt.show()


# 誤差分散の箱ひげ図
fig, axs = plt.subplots(1, 1, figsize=(8, 5))  # サブプロットを作成

ax = axs
allo_data = list(all_error_variance_dict.values())  # allo1, allo2, allo3 のデータリスト
allo_labels = list(all_error_variance_dict.keys())  # alloのラベルリスト
ax.boxplot(allo_data, labels=allo_labels)
# グラフタイトルを設定
ax.set_title(f"{CLUSTERING_METHOD_NAME} の誤差分散の分布", fontsize=21)
ax.set_ylabel("Error variance", fontsize=18)
ax.tick_params(axis="both", which="major", labelsize=15)
ax.set_ylim(0, 50000)

# グラフを表示
plt.tight_layout()  # レイアウトを調整
plt.show()
# Out:
# C:\Users\HaruMomozu\AppData\Local\Temp\ipykernel_3080\4266699732.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(allo_data, labels=allo_labels)
# C:\Users\HaruMomozu\AppData\Local\Temp\ipykernel_3080\4266699732.py:28: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(allo_data, labels=allo_labels)

# %% [markdown]
# ##### 全実験の平均

# %%
# グラフ作成
fig, axs = plt.subplots(
    1,
    1,
    figsize=(8, 5),
)  # サブプロットを作成

ax = axs
allo_data = list(
    mean_reduction_rate_dict.values()
)  # allo1, allo2, allo3 のデータリスト
allo_labels = list(mean_reduction_rate_dict.keys())  # alloのラベルリスト
bars = ax.bar(allo_labels, allo_data)
# 各バーの上に値を表示
for bar in bars:
    yval = bar.get_height()  # 各バーの高さ（値）
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        yval,
        round(yval, 2),
        ha="center",
        va="bottom",
        fontsize=15,
    )  # 値をバーの上に表示
    # plt.ylabel("誤差分散削減率 (%)")
ax.set_ylabel("Error variance reduction rate (%)", fontsize=18)
ax.set_ylim(0, 60)
ax.tick_params(axis="both", which="major", labelsize=15)
ax.set_title(
    f"{CLUSTERING_METHOD_NAME} の誤差分散削減率の平均", fontsize=21
)  # (number of clusters: {clusters})")

plt.tight_layout()
plt.show()


# グラフ作成
fig, axs = plt.subplots(
    1,
    1,
    figsize=(8, 5),
)  # サブプロットを作成

ax = axs
allo_data = list(
    mean_error_variance_dict.values()
)  # allo1, allo2, allo3 のデータリスト
allo_labels = list(mean_error_variance_dict.keys())  # alloのラベルリスト

# bars = ax.bar(allo_labels, allo_data, color="tab:red")
bars = ax.bar(
    allo_labels,
    allo_data,
    color=["blue" if label == "Random" else "tab:red" for label in allo_labels],
)
for bar in bars:
    yval = bar.get_height()  # 各バーの高さ（値）
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        yval,
        round(yval, 2),
        ha="center",
        va="bottom",
        fontsize=15,
    )  # 値をバーの上に表示
ax.set_ylabel("Error variance", fontsize=18)
ax.set_ylim(0, 50000)
ax.tick_params(axis="both", which="major", labelsize=15)
ax.set_title(f"{CLUSTERING_METHOD_NAME} の誤差分散の平均", fontsize=21)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\HaruMomozu\AppData\Local\Temp\ipykernel_3080\1498773511.py:71: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
